# %% [markdown]
# # Capstone Project - The Battle of the Neighborhoods : Report
#
#
# ##### Applied Data Science Capstone by IBM/Coursera
#
#
# ### Table of contents
# - Introduction: Business Problem
# - Data
# - Methodology
# - Analysis
# - Results and Discussion
# - Conclusion
#
# ### Introduction: Business Problem
#
# In this project we will try to find an optimal location for a restaurant. Specifically, this report will be targeted to stakeholders interested in opening an restaurant in Toronto, Canada.
#
# Here we will try finding if someone wants to open a new restaurant in the city which location is best suited for it keeping in mind the competitors and which income group of people will be attracted most to it based on the population of the neighbourhood.
#
# Since there are lots of restaurants in Toronto, we will try to detect locations that are not already crowded with restaurants. We would also prefer locations as close to city center as possible, assuming that first two conditions are met.
#
# We will use our data science powers to generate a few most promissing neighborhoods based on this criteria. Advantages of each area will then be clearly expressed so that best possible final location can be chosen by stakeholders.
#
# ### Data
#
# Based on definition of our problem, factors that will influence our decission are:
#
# -All existing restaurants in the neighborhood (any type of restaurant)
# -Age group of people with their income
# -Distance of neighborhood from city center
#
# We decided to use regularly spaced grid of locations, centered around city center, to define our neighborhoods.
#
# Following data sources will be needed to extract/generate the required information:
#
# -centers of candidate areas will be generated algorithmically and approximate addresses of centers of those areas will be obtained using https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M
# -number of restaurants and their type and location in every neighborhood will be obtained using Foursquare API

# %%
pip install "ipython-beautifulsoup[bs4]"
# Out:
# Requirement already satisfied: ipython-beautifulsoup[bs4] in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (0.3)
# Requirement already satisfied: ipython in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from ipython-beautifulsoup[bs4]) (7.13.0)
# Requirement already satisfied: pygments in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from ipython-beautifulsoup[bs4]) (2.6.1)
# Requirement already satisfied: beautifulsoup4 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from ipython-beautifulsoup[bs4]) (4.9.0)
# Requirement already satisfied: decorator in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from ipython->ipython-beautifulsoup[bs4]) (4.4.2)
# Requirement already satisfied: backcall in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from ipython->ipython-beautifulsoup[bs4]) (0.1.0)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from ipython->ipython-beautifulsoup[bs4]) (3.0.5)
# Requirement already satisfied: pexpect; sys_platform != "win32" in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from ipython->ipython-beautifulsoup[bs4]) (4.8.0)
# Requirement already satisfied: traitlets>=4.2 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from ipython->ipython-beautifulsoup[bs4]) (4.3.3)
# Requirement already satisfied: jedi>=0.10 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from ipython->ipython-beautifulsoup[bs4]) (0.17.0)
# Requirement already satisfied: pickleshare in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from ipython->ipython-beautifulsoup[bs4]) (0.7.5)
# Requirement already satisfied: setuptools>=18.5 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from ipython->ipython-beautifulsoup[bs4]) (46.1.3.post20200325)
# Requirement already satisfied: soupsieve>1.2 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from beautifulsoup4->ipython-beautifulsoup[bs4]) (2.0)
# Requirement already satisfied: wcwidth in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython->ipython-beautifulsoup[bs4]) (0.1.9)
# Requirement already satisfied: ptyprocess>=0.5 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from pexpect; sys_platform != "win32"->ipython->ipython-beautifulsoup[bs4]) (0.6.0)
# Requirement already satisfied: six in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from traitlets>=4.2->ipython->ipython-beautifulsoup[bs4]) (1.14.0)
# Requirement already satisfied: ipython-genutils in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from traitlets>=4.2->ipython->ipython-beautifulsoup[bs4]) (0.2.0)
# Requirement already satisfied: parso>=0.7.0 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from jedi>=0.10->ipython->ipython-beautifulsoup[bs4]) (0.7.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np # library to handle data in a vectorized manner
import pandas as pd # library for data analsysis
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
pd.set_option('display.expand_frame_repr', False)
import json # library to handle JSON files

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# import k-means from clustering stage
from sklearn.cluster import KMeans
from sklearn.datasets.samples_generator import make_blobs

import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

from bs4 import BeautifulSoup

# %%
#!conda install -c conda-forge geopy --yes
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values

# %%
#!conda install -c conda-forge folium=0.5.0 --yes
import folium # map rendering library

# %%
# define the dataframe columns
column_names = ['Postalcode','Borough', 'Neighborhood'] 

df_1 = pd.DataFrame(columns=column_names)

# %% [markdown]
# ##### 1. Download and Explore Dataset

# %%
#Reading the webage
from urllib.request import urlopen
wikki = "https://en.wikipedia.org/w/index.php?title=List_of_postal_codes_of_Canada:_M&oldid=942851379"

webpage = urlopen(wikki)

from bs4 import BeautifulSoup
soup = BeautifulSoup(webpage, "html.parser")

# %%
#Extraxting the table from the webpage
Toronto=soup.find('table', class_='wikitable sortable')

# %%
#Generate lists
Pos=[]
Bor=[]
Neig=[]

for row in Toronto.findAll("tr"):
    cells = row.findAll('td')
    if len(cells)==3: 
        Pos.append(cells[0].find(text=True))
        Bor.append(cells[1].find(text=True))
        Neig.append(cells[2].find(text=True))

        
#Add Data to our DataFrame
df_1['Postalcode']=Pos
df_1['Borough']=Bor
df_1['Neighborhood']=Neig

df_1.head(10)
# Out:
#   Postalcode           Borough      Neighborhood
# 0        M1A      Not assigned    Not assigned\n
# 1        M2A      Not assigned    Not assigned\n
# 2        M3A        North York         Parkwoods
# 3        M4A        North York  Victoria Village
# 4        M5A  Downtown Toronto      Harbourfront
# 5        M6A        North York  Lawrence Heights
# 6        M6A        North York    Lawrence Manor
# 7        M7A  Downtown Toronto      Queen's Park
# 8        M8A      Not assigned    Not assigned\n
# 9        M9A         Etobicoke  Islington Avenue

# %% [markdown]
# ##### Cleaning the Data
# - If Borough is Not Assigned drop row.
# - Reset Index

# %%
df_1=df_1[df_1['Borough']!='Not assigned']
df_1.reset_index(inplace=True)
df_1.head(10)
# Out:
#    index Postalcode           Borough       Neighborhood
# 0      2        M3A        North York          Parkwoods
# 1      3        M4A        North York   Victoria Village
# 2      4        M5A  Downtown Toronto       Harbourfront
# 3      5        M6A        North York   Lawrence Heights
# 4      6        M6A        North York     Lawrence Manor
# 5      7        M7A  Downtown Toronto       Queen's Park
# 6      9        M9A         Etobicoke   Islington Avenue
# 7     10        M1B       Scarborough              Rouge
# 8     11        M1B       Scarborough            Malvern
# 9     13        M3B        North York  Don Mills North\n

# %%
df_1.drop(columns={'index'})
# Out:
#     Postalcode           Borough                                       Neighborhood
# 0          M3A        North York                                          Parkwoods
# 1          M4A        North York                                   Victoria Village
# 2          M5A  Downtown Toronto                                       Harbourfront
# 3          M6A        North York                                   Lawrence Heights
# 4          M6A        North York                                     Lawrence Manor
# 5          M7A  Downtown Toronto                                       Queen's Park
# 6          M9A         Etobicoke                                   Islington Avenue
# 7          M1B       Scarborough                                              Rouge
# 8          M1B       Scarborough                                            Malvern
# 9          M3B        North York                                  Don Mills North\n
# 10         M4B         East York                                   Woodbine Gardens
# 11         M4B         East York                                      Parkview Hill
# 12         M5B  Downtown Toronto                                          Ryerson\n
# 13         M5B  Downtown Toronto                                  Garden District\n
# 14         M6B        North York                                        Glencairn\n
# 15         M9B         Etobicoke                                       Cloverdale\n
# 16         M9B         Etobicoke                                          Islington
# 17         M9B         Etobicoke                                     Martin Grove\n
# 18         M9B         Etobicoke                                   Princess Gardens
# 19         M9B         Etobicoke                                    West Deane Park
# 20         M1C       Scarborough                                     Highland Creek
# 21         M1C       Scarborough                                         Rouge Hill
# 22         M1C       Scarborough                                         Port Union
# 23         M3C        North York                                    Flemingdon Park
# 24         M3C        North York                                  Don Mills South\n
# 25         M4C         East York                                   Woodbine Heights
# 26         M5C  Downtown Toronto                                     St. James Town
# 27         M6C              York                                 Humewood-Cedarvale
# 28         M9C         Etobicoke                                Bloordale Gardens\n
# 29         M9C         Etobicoke                                         Eringate\n
# 30         M9C         Etobicoke                                      Markland Wood
# 31         M9C         Etobicoke                                Old Burnhamthorpe\n
# 32         M1E       Scarborough                                        Guildwood\n
# 33         M1E       Scarborough                                        Morningside
# 34         M1E       Scarborough                                          West Hill
# 35         M4E      East Toronto                                        The Beaches
# 36         M5E  Downtown Toronto                                        Berczy Park
# 37         M6E              York                              Caledonia-Fairbanks\n
# 38         M1G       Scarborough                                             Woburn
# 39         M4G         East York                                            Leaside
# 40         M5G  Downtown Toronto                               Central Bay Street\n
# 41         M6G  Downtown Toronto                                         Christie\n
# 42         M1H       Scarborough                                        Cedarbrae\n
# 43         M2H        North York                                  Hillcrest Village
# 44         M3H        North York                                     Bathurst Manor
# 45         M3H        North York                                  Downsview North\n
# 46         M3H        North York                                     Wilson Heights
# 47         M4H         East York                                   Thorncliffe Park
# 48         M5H  Downtown Toronto                                         Adelaide\n
# 49         M5H  Downtown Toronto                                             King\n
# 50         M5H  Downtown Toronto                                         Richmond\n
# 51         M6H      West Toronto                                 Dovercourt Village
# 52         M6H      West Toronto                                         Dufferin\n
# 53         M1J       Scarborough                                Scarborough Village
# 54         M2J        North York                                         Fairview\n
# 55         M2J        North York                                         Henry Farm
# 56         M2J        North York                                           Oriole\n
# 57         M3J        North York                                     Northwood Park
# 58         M3J        North York                                    York University
# 59         M4J         East York                                       East Toronto
# 60         M5J  Downtown Toronto                                Harbourfront East\n
# 61         M5J  Downtown Toronto                                    Toronto Islands
# 62         M5J  Downtown Toronto                                      Union Station
# 63         M6J      West Toronto                                    Little Portugal
# 64         M6J      West Toronto                                            Trinity
# 65         M1K       Scarborough                             East Birchmount Park\n
# 66         M1K       Scarborough                                            Ionview
# 67         M1K       Scarborough                                       Kennedy Park
# 68         M2K        North York                                    Bayview Village
# 69         M3K        North York                                        CFB Toronto
# 70         M3K        North York                                   Downsview East\n
# 71         M4K      East Toronto                                The Danforth West\n
# 72         M4K      East Toronto                                          Riverdale
# 73         M5K  Downtown Toronto                                    Design Exchange
# 74         M5K  Downtown Toronto                            Toronto Dominion Centre
# 75         M6K      West Toronto                                         Brockton\n
# 76         M6K      West Toronto                                   Exhibition Place
# 77         M6K      West Toronto                                   Parkdale Village
# 78         M1L       Scarborough                                           Clairlea
# 79         M1L       Scarborough                                        Golden Mile
# 80         M1L       Scarborough                                           Oakridge
# 81         M2L        North York                                     Silver Hills\n
# 82         M2L        North York                                         York Mills
# 83         M3L        North York                                     Downsview West
# 84         M4L      East Toronto                                 The Beaches West\n
# 85         M4L      East Toronto                                       India Bazaar
# 86         M5L  Downtown Toronto                                     Commerce Court
# 87         M5L  Downtown Toronto                                   Victoria Hotel\n
# 88         M6L        North York                                          Downsview
# 89         M6L        North York                                       North Park\n
# 90         M6L        North York                                      Upwood Park\n
# 91         M9L        North York                                      Humber Summit
# 92         M1M       Scarborough                                         Cliffcrest
# 93         M1M       Scarborough                                          Cliffside
# 94         M1M       Scarborough                         Scarborough Village West\n
# 95         M2M        North York                                        Newtonbrook
# 96         M2M        North York                                         Willowdale
# 97         M3M        North York                                Downsview Central\n
# 98         M4M      East Toronto                                  Studio District\n
# 99         M5M        North York                                       Bedford Park
# 100        M5M        North York                              Lawrence Manor East\n
# 101        M6M              York                                          Del Ray\n
# 102        M6M              York                                         Keelesdale
# 103        M6M              York                                       Mount Dennis
# 104        M6M              York                                        Silverthorn
# 105        M9M        North York                                              Emery
# 106        M9M        North York                                          Humberlea
# 107        M1N       Scarborough                                        Birch Cliff
# 108        M1N       Scarborough                                   Cliffside West\n
# 109        M2N        North York                                 Willowdale South\n
# 110        M3N        North York                              Downsview Northwest\n
# 111        M4N   Central Toronto                                      Lawrence Park
# 112        M5N   Central Toronto                                         Roselawn\n
# 113        M6N              York                               The Junction North\n
# 114        M6N              York                                        Runnymede\n
# 115        M9N              York                                             Weston
# 116        M1P       Scarborough                                        Dorset Park
# 117        M1P       Scarborough                            Scarborough Town Centre
# 118        M1P       Scarborough                                    Wexford Heights
# 119        M2P        North York                                  York Mills West\n
# 120        M4P   Central Toronto                                 Davisville North\n
# 121        M5P   Central Toronto                                  Forest Hill North
# 122        M5P   Central Toronto                                 Forest Hill West\n
# 123        M6P      West Toronto                                          High Park
# 124        M6P      West Toronto                               The Junction South\n
# 125        M9P         Etobicoke                                        Westmount\n
# 126        M1R       Scarborough                                           Maryvale
# 127        M1R       Scarborough                                            Wexford
# 128        M2R        North York                                    Willowdale West
# 129        M4R   Central Toronto                               North Toronto West\n
# 130        M5R   Central Toronto                                          The Annex
# 131        M5R   Central Toronto                                    North Midtown\n
# 132        M5R   Central Toronto                                          Yorkville
# 133        M6R      West Toronto                                           Parkdale
# 134        M6R      West Toronto                                       Roncesvalles
# 135        M7R       Mississauga            Canada Post Gateway Processing Centre\n
# 136        M9R         Etobicoke                                  Kingsview Village
# 137        M9R         Etobicoke                             Martin Grove Gardens\n
# 138        M9R         Etobicoke                                 Richview Gardens\n
# 139        M9R         Etobicoke                                     St. Phillips\n
# 140        M1S       Scarborough                                          Agincourt
# 141        M4S   Central Toronto                                       Davisville\n
# 142        M5S  Downtown Toronto                                          Harbord\n
# 143        M5S  Downtown Toronto                              University of Toronto
# 144        M6S      West Toronto                                          Runnymede
# 145        M6S      West Toronto                                            Swansea
# 146        M1T       Scarborough                                   Clarks Corners\n
# 147        M1T       Scarborough                                         Sullivan\n
# 148        M1T       Scarborough                                      Tam O'Shanter
# 149        M4T   Central Toronto                                         Moore Park
# 150        M4T   Central Toronto                                  Summerhill East\n
# 151        M5T  Downtown Toronto                                          Chinatown
# 152        M5T  Downtown Toronto                                        Grange Park
# 153        M5T  Downtown Toronto                                  Kensington Market
# 154        M1V       Scarborough                                    Agincourt North
# 155        M1V       Scarborough                                  L'Amoreaux East\n
# 156        M1V       Scarborough                                           Milliken
# 157        M1V       Scarborough                                     Steeles East\n
# 158        M4V   Central Toronto                                          Deer Park
# 159        M4V   Central Toronto                                   Forest Hill SE\n
# 160        M4V   Central Toronto                                          Rathnelly
# 161        M4V   Central Toronto                                         South Hill
# 162        M4V   Central Toronto                                  Summerhill West\n
# 163        M5V  Downtown Toronto                                           CN Tower
# 164        M5V  Downtown Toronto                                    Bathurst Quay\n
# 165        M5V  Downtown Toronto                                   Island airport\n
# 166        M5V  Downtown Toronto                                Harbourfront West\n
# 167        M5V  Downtown Toronto                                   King and Spadina
# 168        M5V  Downtown Toronto                                      Railway Lands
# 169        M5V  Downtown Toronto                                      South Niagara
# 170        M8V         Etobicoke                                Humber Bay Shores\n
# 171        M8V         Etobicoke                                     Mimico South\n
# 172        M8V         Etobicoke                                        New Toronto
# 173        M9V         Etobicoke                                   Albion Gardens\n
# 174        M9V         Etobicoke                                   Beaumond Heights
# 175        M9V         Etobicoke                                       Humbergate\n
# 176        M9V         Etobicoke                                          Jamestown
# 177        M9V         Etobicoke                                        Mount Olive
# 178        M9V         Etobicoke                                        Silverstone
# 179        M9V         Etobicoke                                      South Steeles
# 180        M9V         Etobicoke                                        Thistletown
# 181        M1W       Scarborough                                  L'Amoreaux West\n
# 182        M4W  Downtown Toronto                                           Rosedale
# 183        M5W  Downtown Toronto                  Stn A PO Boxes 25 The Esplanade\n
# 184        M8W         Etobicoke                                          Alderwood
# 185        M8W         Etobicoke                                        Long Branch
# 186        M9W         Etobicoke                                        Northwest\n
# 187        M1X       Scarborough                                        Upper Rouge
# 188        M4X  Downtown Toronto                                        Cabbagetown
# 189        M4X  Downtown Toronto                                     St. James Town
# 190        M5X  Downtown Toronto                               First Canadian Place
# 191        M5X  Downtown Toronto                                   Underground city
# 192        M8X         Etobicoke                                       The Kingsway
# 193        M8X         Etobicoke                                  Montgomery Road\n
# 194        M8X         Etobicoke                                   Old Mill North\n
# 195        M4Y  Downtown Toronto                               Church and Wellesley
# 196        M7Y      East Toronto  Business Reply Mail Processing Centre 969 East...
# 197        M8Y         Etobicoke                                         Humber Bay
# 198        M8Y         Etobicoke                                 King's Mill Park\n
# 199        M8Y         Etobicoke                         Kingsway Park South East\n
# 200        M8Y         Etobicoke                                          Mimico NE
# 201        M8Y         Etobicoke                                     Old Mill South
# 202        M8Y         Etobicoke                                 The Queensway East
# 203        M8Y         Etobicoke                              Royal York South East
# 204        M8Y         Etobicoke                                           Sunnylea
# 205        M8Z         Etobicoke                         Kingsway Park South West\n
# 206        M8Z         Etobicoke                                          Mimico NW
# 207        M8Z         Etobicoke                                 The Queensway West
# 208        M8Z         Etobicoke                            Royal York South West\n
# 209        M8Z         Etobicoke                                   South of Bloor\n

# %%
df_2 = df_1.groupby('Postalcode')['Neighborhood'].apply(lambda x: "%s" % ', '.join(x))
df_2 = df_2.reset_index(drop=False)
df_2.rename(columns={'Neighborhood':'Neighborhood_joined'},inplace=True)
df_2.head()
# Out:
#   Postalcode                     Neighborhood_joined
# 0        M1B                          Rouge, Malvern
# 1        M1C  Highland Creek, Rouge Hill, Port Union
# 2        M1E     Guildwood\n, Morningside, West Hill
# 3        M1G                                  Woburn
# 4        M1H                             Cedarbrae\n

# %%
df_3 = pd.merge(df_1, df_2, on='Postalcode')
df_3.drop(['Neighborhood'], axis=1, inplace = True)
df_3.drop_duplicates( inplace = True)
df_3.rename(columns={'Neighborhood_joined': 'Neighborhood'}, inplace = True)
df_3.head()
# Out:
#    index Postalcode           Borough                      Neighborhood
# 0      2        M3A        North York                         Parkwoods
# 1      3        M4A        North York                  Victoria Village
# 2      4        M5A  Downtown Toronto                      Harbourfront
# 3      5        M6A        North York  Lawrence Heights, Lawrence Manor
# 4      6        M6A        North York  Lawrence Heights, Lawrence Manor

# %%
df_3.drop(columns={'index'})
# Out:
#     Postalcode           Borough                                       Neighborhood
# 0          M3A        North York                                          Parkwoods
# 1          M4A        North York                                   Victoria Village
# 2          M5A  Downtown Toronto                                       Harbourfront
# 3          M6A        North York                   Lawrence Heights, Lawrence Manor
# 4          M6A        North York                   Lawrence Heights, Lawrence Manor
# 5          M7A  Downtown Toronto                                       Queen's Park
# 6          M9A         Etobicoke                                   Islington Avenue
# 7          M1B       Scarborough                                     Rouge, Malvern
# 8          M1B       Scarborough                                     Rouge, Malvern
# 9          M3B        North York                                  Don Mills North\n
# 10         M4B         East York                    Woodbine Gardens, Parkview Hill
# 11         M4B         East York                    Woodbine Gardens, Parkview Hill
# 12         M5B  Downtown Toronto                       Ryerson\n, Garden District\n
# 13         M5B  Downtown Toronto                       Ryerson\n, Garden District\n
# 14         M6B        North York                                        Glencairn\n
# 15         M9B         Etobicoke  Cloverdale\n, Islington, Martin Grove\n, Princ...
# 16         M9B         Etobicoke  Cloverdale\n, Islington, Martin Grove\n, Princ...
# 17         M9B         Etobicoke  Cloverdale\n, Islington, Martin Grove\n, Princ...
# 18         M9B         Etobicoke  Cloverdale\n, Islington, Martin Grove\n, Princ...
# 19         M9B         Etobicoke  Cloverdale\n, Islington, Martin Grove\n, Princ...
# 20         M1C       Scarborough             Highland Creek, Rouge Hill, Port Union
# 21         M1C       Scarborough             Highland Creek, Rouge Hill, Port Union
# 22         M1C       Scarborough             Highland Creek, Rouge Hill, Port Union
# 23         M3C        North York                 Flemingdon Park, Don Mills South\n
# 24         M3C        North York                 Flemingdon Park, Don Mills South\n
# 25         M4C         East York                                   Woodbine Heights
# 26         M5C  Downtown Toronto                                     St. James Town
# 27         M6C              York                                 Humewood-Cedarvale
# 28         M9C         Etobicoke  Bloordale Gardens\n, Eringate\n, Markland Wood...
# 29         M9C         Etobicoke  Bloordale Gardens\n, Eringate\n, Markland Wood...
# 30         M9C         Etobicoke  Bloordale Gardens\n, Eringate\n, Markland Wood...
# 31         M9C         Etobicoke  Bloordale Gardens\n, Eringate\n, Markland Wood...
# 32         M1E       Scarborough                Guildwood\n, Morningside, West Hill
# 33         M1E       Scarborough                Guildwood\n, Morningside, West Hill
# 34         M1E       Scarborough                Guildwood\n, Morningside, West Hill
# 35         M4E      East Toronto                                        The Beaches
# 36         M5E  Downtown Toronto                                        Berczy Park
# 37         M6E              York                              Caledonia-Fairbanks\n
# 38         M1G       Scarborough                                             Woburn
# 39         M4G         East York                                            Leaside
# 40         M5G  Downtown Toronto                               Central Bay Street\n
# 41         M6G  Downtown Toronto                                         Christie\n
# 42         M1H       Scarborough                                        Cedarbrae\n
# 43         M2H        North York                                  Hillcrest Village
# 44         M3H        North York  Bathurst Manor, Downsview North\n, Wilson Heights
# 45         M3H        North York  Bathurst Manor, Downsview North\n, Wilson Heights
# 46         M3H        North York  Bathurst Manor, Downsview North\n, Wilson Heights
# 47         M4H         East York                                   Thorncliffe Park
# 48         M5H  Downtown Toronto                     Adelaide\n, King\n, Richmond\n
# 49         M5H  Downtown Toronto                     Adelaide\n, King\n, Richmond\n
# 50         M5H  Downtown Toronto                     Adelaide\n, King\n, Richmond\n
# 51         M6H      West Toronto                     Dovercourt Village, Dufferin\n
# 52         M6H      West Toronto                     Dovercourt Village, Dufferin\n
# 53         M1J       Scarborough                                Scarborough Village
# 54         M2J        North York                   Fairview\n, Henry Farm, Oriole\n
# 55         M2J        North York                   Fairview\n, Henry Farm, Oriole\n
# 56         M2J        North York                   Fairview\n, Henry Farm, Oriole\n
# 57         M3J        North York                    Northwood Park, York University
# 58         M3J        North York                    Northwood Park, York University
# 59         M4J         East York                                       East Toronto
# 60         M5J  Downtown Toronto  Harbourfront East\n, Toronto Islands, Union St...
# 61         M5J  Downtown Toronto  Harbourfront East\n, Toronto Islands, Union St...
# 62         M5J  Downtown Toronto  Harbourfront East\n, Toronto Islands, Union St...
# 63         M6J      West Toronto                           Little Portugal, Trinity
# 64         M6J      West Toronto                           Little Portugal, Trinity
# 65         M1K       Scarborough      East Birchmount Park\n, Ionview, Kennedy Park
# 66         M1K       Scarborough      East Birchmount Park\n, Ionview, Kennedy Park
# 67         M1K       Scarborough      East Birchmount Park\n, Ionview, Kennedy Park
# 68         M2K        North York                                    Bayview Village
# 69         M3K        North York                      CFB Toronto, Downsview East\n
# 70         M3K        North York                      CFB Toronto, Downsview East\n
# 71         M4K      East Toronto                     The Danforth West\n, Riverdale
# 72         M4K      East Toronto                     The Danforth West\n, Riverdale
# 73         M5K  Downtown Toronto           Design Exchange, Toronto Dominion Centre
# 74         M5K  Downtown Toronto           Design Exchange, Toronto Dominion Centre
# 75         M6K      West Toronto     Brockton\n, Exhibition Place, Parkdale Village
# 76         M6K      West Toronto     Brockton\n, Exhibition Place, Parkdale Village
# 77         M6K      West Toronto     Brockton\n, Exhibition Place, Parkdale Village
# 78         M1L       Scarborough                    Clairlea, Golden Mile, Oakridge
# 79         M1L       Scarborough                    Clairlea, Golden Mile, Oakridge
# 80         M1L       Scarborough                    Clairlea, Golden Mile, Oakridge
# 81         M2L        North York                         Silver Hills\n, York Mills
# 82         M2L        North York                         Silver Hills\n, York Mills
# 83         M3L        North York                                     Downsview West
# 84         M4L      East Toronto                   The Beaches West\n, India Bazaar
# 85         M4L      East Toronto                   The Beaches West\n, India Bazaar
# 86         M5L  Downtown Toronto                   Commerce Court, Victoria Hotel\n
# 87         M5L  Downtown Toronto                   Commerce Court, Victoria Hotel\n
# 88         M6L        North York             Downsview, North Park\n, Upwood Park\n
# 89         M6L        North York             Downsview, North Park\n, Upwood Park\n
# 90         M6L        North York             Downsview, North Park\n, Upwood Park\n
# 91         M9L        North York                                      Humber Summit
# 92         M1M       Scarborough  Cliffcrest, Cliffside, Scarborough Village West\n
# 93         M1M       Scarborough  Cliffcrest, Cliffside, Scarborough Village West\n
# 94         M1M       Scarborough  Cliffcrest, Cliffside, Scarborough Village West\n
# 95         M2M        North York                            Newtonbrook, Willowdale
# 96         M2M        North York                            Newtonbrook, Willowdale
# 97         M3M        North York                                Downsview Central\n
# 98         M4M      East Toronto                                  Studio District\n
# 99         M5M        North York                Bedford Park, Lawrence Manor East\n
# 100        M5M        North York                Bedford Park, Lawrence Manor East\n
# 101        M6M              York   Del Ray\n, Keelesdale, Mount Dennis, Silverthorn
# 102        M6M              York   Del Ray\n, Keelesdale, Mount Dennis, Silverthorn
# 103        M6M              York   Del Ray\n, Keelesdale, Mount Dennis, Silverthorn
# 104        M6M              York   Del Ray\n, Keelesdale, Mount Dennis, Silverthorn
# 105        M9M        North York                                   Emery, Humberlea
# 106        M9M        North York                                   Emery, Humberlea
# 107        M1N       Scarborough                      Birch Cliff, Cliffside West\n
# 108        M1N       Scarborough                      Birch Cliff, Cliffside West\n
# 109        M2N        North York                                 Willowdale South\n
# 110        M3N        North York                              Downsview Northwest\n
# 111        M4N   Central Toronto                                      Lawrence Park
# 112        M5N   Central Toronto                                         Roselawn\n
# 113        M6N              York                  The Junction North\n, Runnymede\n
# 114        M6N              York                  The Junction North\n, Runnymede\n
# 115        M9N              York                                             Weston
# 116        M1P       Scarborough  Dorset Park, Scarborough Town Centre, Wexford ...
# 117        M1P       Scarborough  Dorset Park, Scarborough Town Centre, Wexford ...
# 118        M1P       Scarborough  Dorset Park, Scarborough Town Centre, Wexford ...
# 119        M2P        North York                                  York Mills West\n
# 120        M4P   Central Toronto                                 Davisville North\n
# 121        M5P   Central Toronto              Forest Hill North, Forest Hill West\n
# 122        M5P   Central Toronto              Forest Hill North, Forest Hill West\n
# 123        M6P      West Toronto                    High Park, The Junction South\n
# 124        M6P      West Toronto                    High Park, The Junction South\n
# 125        M9P         Etobicoke                                        Westmount\n
# 126        M1R       Scarborough                                  Maryvale, Wexford
# 127        M1R       Scarborough                                  Maryvale, Wexford
# 128        M2R        North York                                    Willowdale West
# 129        M4R   Central Toronto                               North Toronto West\n
# 130        M5R   Central Toronto              The Annex, North Midtown\n, Yorkville
# 131        M5R   Central Toronto              The Annex, North Midtown\n, Yorkville
# 132        M5R   Central Toronto              The Annex, North Midtown\n, Yorkville
# 133        M6R      West Toronto                             Parkdale, Roncesvalles
# 134        M6R      West Toronto                             Parkdale, Roncesvalles
# 135        M7R       Mississauga            Canada Post Gateway Processing Centre\n
# 136        M9R         Etobicoke  Kingsview Village, Martin Grove Gardens\n, Ric...
# 137        M9R         Etobicoke  Kingsview Village, Martin Grove Gardens\n, Ric...
# 138        M9R         Etobicoke  Kingsview Village, Martin Grove Gardens\n, Ric...
# 139        M9R         Etobicoke  Kingsview Village, Martin Grove Gardens\n, Ric...
# 140        M1S       Scarborough                                          Agincourt
# 141        M4S   Central Toronto                                       Davisville\n
# 142        M5S  Downtown Toronto                   Harbord\n, University of Toronto
# 143        M5S  Downtown Toronto                   Harbord\n, University of Toronto
# 144        M6S      West Toronto                                 Runnymede, Swansea
# 145        M6S      West Toronto                                 Runnymede, Swansea
# 146        M1T       Scarborough        Clarks Corners\n, Sullivan\n, Tam O'Shanter
# 147        M1T       Scarborough        Clarks Corners\n, Sullivan\n, Tam O'Shanter
# 148        M1T       Scarborough        Clarks Corners\n, Sullivan\n, Tam O'Shanter
# 149        M4T   Central Toronto                      Moore Park, Summerhill East\n
# 150        M4T   Central Toronto                      Moore Park, Summerhill East\n
# 151        M5T  Downtown Toronto          Chinatown, Grange Park, Kensington Market
# 152        M5T  Downtown Toronto          Chinatown, Grange Park, Kensington Market
# 153        M5T  Downtown Toronto          Chinatown, Grange Park, Kensington Market
# 154        M1V       Scarborough  Agincourt North, L'Amoreaux East\n, Milliken, ...
# 155        M1V       Scarborough  Agincourt North, L'Amoreaux East\n, Milliken, ...
# 156        M1V       Scarborough  Agincourt North, L'Amoreaux East\n, Milliken, ...
# 157        M1V       Scarborough  Agincourt North, L'Amoreaux East\n, Milliken, ...
# 158        M4V   Central Toronto  Deer Park, Forest Hill SE\n, Rathnelly, South ...
# 159        M4V   Central Toronto  Deer Park, Forest Hill SE\n, Rathnelly, South ...
# 160        M4V   Central Toronto  Deer Park, Forest Hill SE\n, Rathnelly, South ...
# 161        M4V   Central Toronto  Deer Park, Forest Hill SE\n, Rathnelly, South ...
# 162        M4V   Central Toronto  Deer Park, Forest Hill SE\n, Rathnelly, South ...
# 163        M5V  Downtown Toronto  CN Tower, Bathurst Quay\n, Island airport\n, H...
# 164        M5V  Downtown Toronto  CN Tower, Bathurst Quay\n, Island airport\n, H...
# 165        M5V  Downtown Toronto  CN Tower, Bathurst Quay\n, Island airport\n, H...
# 166        M5V  Downtown Toronto  CN Tower, Bathurst Quay\n, Island airport\n, H...
# 167        M5V  Downtown Toronto  CN Tower, Bathurst Quay\n, Island airport\n, H...
# 168        M5V  Downtown Toronto  CN Tower, Bathurst Quay\n, Island airport\n, H...
# 169        M5V  Downtown Toronto  CN Tower, Bathurst Quay\n, Island airport\n, H...
# 170        M8V         Etobicoke   Humber Bay Shores\n, Mimico South\n, New Toronto
# 171        M8V         Etobicoke   Humber Bay Shores\n, Mimico South\n, New Toronto
# 172        M8V         Etobicoke   Humber Bay Shores\n, Mimico South\n, New Toronto
# 173        M9V         Etobicoke  Albion Gardens\n, Beaumond Heights, Humbergate...
# 174        M9V         Etobicoke  Albion Gardens\n, Beaumond Heights, Humbergate...
# 175        M9V         Etobicoke  Albion Gardens\n, Beaumond Heights, Humbergate...
# 176        M9V         Etobicoke  Albion Gardens\n, Beaumond Heights, Humbergate...
# 177        M9V         Etobicoke  Albion Gardens\n, Beaumond Heights, Humbergate...
# 178        M9V         Etobicoke  Albion Gardens\n, Beaumond Heights, Humbergate...
# 179        M9V         Etobicoke  Albion Gardens\n, Beaumond Heights, Humbergate...
# 180        M9V         Etobicoke  Albion Gardens\n, Beaumond Heights, Humbergate...
# 181        M1W       Scarborough                                  L'Amoreaux West\n
# 182        M4W  Downtown Toronto                                           Rosedale
# 183        M5W  Downtown Toronto                  Stn A PO Boxes 25 The Esplanade\n
# 184        M8W         Etobicoke                             Alderwood, Long Branch
# 185        M8W         Etobicoke                             Alderwood, Long Branch
# 186        M9W         Etobicoke                                        Northwest\n
# 187        M1X       Scarborough                                        Upper Rouge
# 188        M4X  Downtown Toronto                        Cabbagetown, St. James Town
# 189        M4X  Downtown Toronto                        Cabbagetown, St. James Town
# 190        M5X  Downtown Toronto             First Canadian Place, Underground city
# 191        M5X  Downtown Toronto             First Canadian Place, Underground city
# 192        M8X         Etobicoke  The Kingsway, Montgomery Road\n, Old Mill North\n
# 193        M8X         Etobicoke  The Kingsway, Montgomery Road\n, Old Mill North\n
# 194        M8X         Etobicoke  The Kingsway, Montgomery Road\n, Old Mill North\n
# 195        M4Y  Downtown Toronto                               Church and Wellesley
# 196        M7Y      East Toronto  Business Reply Mail Processing Centre 969 East...
# 197        M8Y         Etobicoke  Humber Bay, King's Mill Park\n, Kingsway Park ...
# 198        M8Y         Etobicoke  Humber Bay, King's Mill Park\n, Kingsway Park ...
# 199        M8Y         Etobicoke  Humber Bay, King's Mill Park\n, Kingsway Park ...
# 200        M8Y         Etobicoke  Humber Bay, King's Mill Park\n, Kingsway Park ...
# 201        M8Y         Etobicoke  Humber Bay, King's Mill Park\n, Kingsway Park ...
# 202        M8Y         Etobicoke  Humber Bay, King's Mill Park\n, Kingsway Park ...
# 203        M8Y         Etobicoke  Humber Bay, King's Mill Park\n, Kingsway Park ...
# 204        M8Y         Etobicoke  Humber Bay, King's Mill Park\n, Kingsway Park ...
# 205        M8Z         Etobicoke  Kingsway Park South West\n, Mimico NW, The Que...
# 206        M8Z         Etobicoke  Kingsway Park South West\n, Mimico NW, The Que...
# 207        M8Z         Etobicoke  Kingsway Park South West\n, Mimico NW, The Que...
# 208        M8Z         Etobicoke  Kingsway Park South West\n, Mimico NW, The Que...
# 209        M8Z         Etobicoke  Kingsway Park South West\n, Mimico NW, The Que...

# %%
column = ['Postal_Code','Borough', 'Neighborhood'] 
df_ungrp = pd.DataFrame(columns=column_names)

df_ungrp = df_1.drop(df_1[df_1['Borough'].str.contains("Toronto")==False].index, axis=0, inplace=False)


df_ungrp.index = pd.RangeIndex(len(df_ungrp.index))
df_ungrp
# Out:
#     index Postalcode           Borough                                       Neighborhood
# 0       4        M5A  Downtown Toronto                                       Harbourfront
# 1       7        M7A  Downtown Toronto                                       Queen's Park
# 2      16        M5B  Downtown Toronto                                          Ryerson\n
# 3      17        M5B  Downtown Toronto                                  Garden District\n
# 4      33        M5C  Downtown Toronto                                     St. James Town
# 5      46        M4E      East Toronto                                        The Beaches
# 6      47        M5E  Downtown Toronto                                        Berczy Park
# 7      56        M5G  Downtown Toronto                               Central Bay Street\n
# 8      57        M6G  Downtown Toronto                                         Christie\n
# 9      67        M5H  Downtown Toronto                                         Adelaide\n
# 10     68        M5H  Downtown Toronto                                             King\n
# 11     69        M5H  Downtown Toronto                                         Richmond\n
# 12     70        M6H      West Toronto                                 Dovercourt Village
# 13     71        M6H      West Toronto                                         Dufferin\n
# 14     82        M5J  Downtown Toronto                                Harbourfront East\n
# 15     83        M5J  Downtown Toronto                                    Toronto Islands
# 16     84        M5J  Downtown Toronto                                      Union Station
# 17     85        M6J      West Toronto                                    Little Portugal
# 18     86        M6J      West Toronto                                            Trinity
# 19     96        M4K      East Toronto                                The Danforth West\n
# 20     97        M4K      East Toronto                                          Riverdale
# 21     98        M5K  Downtown Toronto                                    Design Exchange
# 22     99        M5K  Downtown Toronto                            Toronto Dominion Centre
# 23    100        M6K      West Toronto                                         Brockton\n
# 24    101        M6K      West Toronto                                   Exhibition Place
# 25    102        M6K      West Toronto                                   Parkdale Village
# 26    112        M4L      East Toronto                                 The Beaches West\n
# 27    113        M4L      East Toronto                                       India Bazaar
# 28    114        M5L  Downtown Toronto                                     Commerce Court
# 29    115        M5L  Downtown Toronto                                   Victoria Hotel\n
# 30    128        M4M      East Toronto                                  Studio District\n
# 31    143        M4N   Central Toronto                                      Lawrence Park
# 32    144        M5N   Central Toronto                                         Roselawn\n
# 33    155        M4P   Central Toronto                                 Davisville North\n
# 34    156        M5P   Central Toronto                                  Forest Hill North
# 35    157        M5P   Central Toronto                                 Forest Hill West\n
# 36    158        M6P      West Toronto                                          High Park
# 37    159        M6P      West Toronto                               The Junction South\n
# 38    167        M4R   Central Toronto                               North Toronto West\n
# 39    168        M5R   Central Toronto                                          The Annex
# 40    169        M5R   Central Toronto                                    North Midtown\n
# 41    170        M5R   Central Toronto                                          Yorkville
# 42    171        M6R      West Toronto                                           Parkdale
# 43    172        M6R      West Toronto                                       Roncesvalles
# 44    182        M4S   Central Toronto                                       Davisville\n
# 45    183        M5S  Downtown Toronto                                          Harbord\n
# 46    184        M5S  Downtown Toronto                              University of Toronto
# 47    185        M6S      West Toronto                                          Runnymede
# 48    186        M6S      West Toronto                                            Swansea
# 49    195        M4T   Central Toronto                                         Moore Park
# 50    196        M4T   Central Toronto                                  Summerhill East\n
# 51    197        M5T  Downtown Toronto                                          Chinatown
# 52    198        M5T  Downtown Toronto                                        Grange Park
# 53    199        M5T  Downtown Toronto                                  Kensington Market
# 54    210        M4V   Central Toronto                                          Deer Park
# 55    211        M4V   Central Toronto                                   Forest Hill SE\n
# 56    212        M4V   Central Toronto                                          Rathnelly
# 57    213        M4V   Central Toronto                                         South Hill
# 58    214        M4V   Central Toronto                                  Summerhill West\n
# 59    215        M5V  Downtown Toronto                                           CN Tower
# 60    216        M5V  Downtown Toronto                                    Bathurst Quay\n
# 61    217        M5V  Downtown Toronto                                   Island airport\n
# 62    218        M5V  Downtown Toronto                                Harbourfront West\n
# 63    219        M5V  Downtown Toronto                                   King and Spadina
# 64    220        M5V  Downtown Toronto                                      Railway Lands
# 65    221        M5V  Downtown Toronto                                      South Niagara
# 66    238        M4W  Downtown Toronto                                           Rosedale
# 67    239        M5W  Downtown Toronto                  Stn A PO Boxes 25 The Esplanade\n
# 68    248        M4X  Downtown Toronto                                        Cabbagetown
# 69    249        M4X  Downtown Toronto                                     St. James Town
# 70    250        M5X  Downtown Toronto                               First Canadian Place
# 71    251        M5X  Downtown Toronto                                   Underground city
# 72    261        M4Y  Downtown Toronto                               Church and Wellesley
# 73    264        M7Y      East Toronto  Business Reply Mail Processing Centre 969 East...

# %%
df_ungrp.drop(columns={'index'},inplace=True)

# %%
import time

# %%
geolocator = Nominatim(scheme='http', user_agent="ES1234")

for row_index, item in df_ungrp.iterrows():
    
    list1 = df_ungrp.loc[[row_index],['Neighborhood']].values.astype('str')
    loc = ' , Toronto, Ontario, Canada'
    list1.astype('str')
    list1 = np.append(list1, loc)
    latitude = None
    longitude = None
    location = None
    
    location = geolocator.geocode(list1 , limit = 15)
    #time.sleep(5)
    if(location is not None):
        df_ungrp.loc[df_ungrp.index[row_index], 'Latitude'] = location.latitude
        df_ungrp.loc[df_ungrp.index[row_index], 'Longitude'] = location.longitude

# %%
df_ungrp.head(10)
# Out:
#   Postalcode           Borough          Neighborhood   Latitude  Longitude
# 0        M5A  Downtown Toronto          Harbourfront  43.640080 -79.380150
# 1        M7A  Downtown Toronto          Queen's Park  43.659659 -79.390340
# 2        M5B  Downtown Toronto             Ryerson\n  43.658469 -79.378993
# 3        M5B  Downtown Toronto     Garden District\n  43.656500 -79.377114
# 4        M5C  Downtown Toronto        St. James Town  43.669403 -79.372704
# 5        M4E      East Toronto           The Beaches  43.671024 -79.296712
# 6        M5E  Downtown Toronto           Berczy Park  43.647984 -79.375396
# 7        M5G  Downtown Toronto  Central Bay Street\n        NaN        NaN
# 8        M6G  Downtown Toronto            Christie\n  43.664111 -79.418405
# 9        M5H  Downtown Toronto            Adelaide\n  43.650486 -79.379498

# %%
print('We have {} boroughs and {} neighborhoods.'.format(
        len(df_ungrp['Borough'].unique()),
        df_ungrp.shape[0]
    )
)

df_ungrp.dropna(inplace =True)

address = 'Toronto, Ontario, Canada'

geolocator = Nominatim(user_agent="ES1234")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Toronto are {}, {}.'.format(latitude, longitude))
# Out:
# We have 4 boroughs and 74 neighborhoods.
# The geograpical coordinate of Toronto are 43.6534817, -79.3839347.

# %%
df_ungrp.reset_index(inplace=True)
df_ungrp
# Out:
#     index Postalcode           Borough             Neighborhood   Latitude  Longitude
# 0       0        M5A  Downtown Toronto             Harbourfront  43.640080 -79.380150
# 1       1        M7A  Downtown Toronto             Queen's Park  43.659659 -79.390340
# 2       2        M5B  Downtown Toronto                Ryerson\n  43.658469 -79.378993
# 3       3        M5B  Downtown Toronto        Garden District\n  43.656500 -79.377114
# 4       4        M5C  Downtown Toronto           St. James Town  43.669403 -79.372704
# 5       5        M4E      East Toronto              The Beaches  43.671024 -79.296712
# 6       6        M5E  Downtown Toronto              Berczy Park  43.647984 -79.375396
# 7       8        M6G  Downtown Toronto               Christie\n  43.664111 -79.418405
# 8       9        M5H  Downtown Toronto               Adelaide\n  43.650486 -79.379498
# 9      10        M5H  Downtown Toronto                   King\n  43.648949 -79.377754
# 10     11        M5H  Downtown Toronto               Richmond\n  43.812589 -79.263370
# 11     12        M6H      West Toronto       Dovercourt Village  43.665307 -79.432636
# 12     13        M6H      West Toronto               Dufferin\n  43.660202 -79.435719
# 13     14        M5J  Downtown Toronto      Harbourfront East\n  43.640080 -79.380150
# 14     15        M5J  Downtown Toronto          Toronto Islands  43.623054 -79.394316
# 15     16        M5J  Downtown Toronto            Union Station  43.644693 -79.380132
# 16     17        M6J      West Toronto          Little Portugal  43.647413 -79.431116
# 17     18        M6J      West Toronto                  Trinity  43.665302 -79.395252
# 18     19        M4K      East Toronto      The Danforth West\n  43.687017 -79.297511
# 19     20        M4K      East Toronto                Riverdale  43.665470 -79.352594
# 20     21        M5K  Downtown Toronto          Design Exchange  43.647741 -79.380115
# 21     22        M5K  Downtown Toronto  Toronto Dominion Centre  43.647377 -79.381372
# 22     23        M6K      West Toronto               Brockton\n  43.650917 -79.440022
# 23     24        M6K      West Toronto         Exhibition Place  43.633469 -79.417865
# 24     25        M6K      West Toronto         Parkdale Village  43.640495 -79.436897
# 25     26        M4L      East Toronto       The Beaches West\n  43.671024 -79.296712
# 26     27        M4L      East Toronto             India Bazaar  43.672223 -79.323503
# 27     28        M5L  Downtown Toronto           Commerce Court  43.648095 -79.379025
# 28     30        M4M      East Toronto        Studio District\n  43.649585 -79.390683
# 29     31        M4N   Central Toronto            Lawrence Park  43.729199 -79.403252
# 30     32        M5N   Central Toronto               Roselawn\n  43.710541 -79.401138
# 31     33        M4P   Central Toronto       Davisville North\n  43.704312 -79.388517
# 32     34        M5P   Central Toronto        Forest Hill North  43.693559 -79.413902
# 33     36        M6P      West Toronto                High Park  43.653867 -79.466864
# 34     37        M6P      West Toronto     The Junction South\n  43.665478 -79.470352
# 35     39        M5R   Central Toronto                The Annex  43.670338 -79.407117
# 36     41        M5R   Central Toronto                Yorkville  43.671386 -79.390168
# 37     42        M6R      West Toronto                 Parkdale  43.640495 -79.436897
# 38     43        M6R      West Toronto             Roncesvalles  43.651443 -79.451038
# 39     44        M4S   Central Toronto             Davisville\n  43.697936 -79.397291
# 40     45        M5S  Downtown Toronto                Harbord\n  43.661512 -79.414391
# 41     46        M5S  Downtown Toronto    University of Toronto  43.663462 -79.397760
# 42     47        M6S      West Toronto                Runnymede  43.651703 -79.475998
# 43     48        M6S      West Toronto                  Swansea  43.644940 -79.478313
# 44     49        M4T   Central Toronto               Moore Park  43.690388 -79.383297
# 45     50        M4T   Central Toronto        Summerhill East\n  43.681678 -79.390504
# 46     51        M5T  Downtown Toronto                Chinatown  43.652924 -79.398032
# 47     52        M5T  Downtown Toronto              Grange Park  43.652197 -79.392319
# 48     53        M5T  Downtown Toronto        Kensington Market  43.655214 -79.402260
# 49     54        M4V   Central Toronto                Deer Park  43.688090 -79.394093
# 50     55        M4V   Central Toronto         Forest Hill SE\n  43.693559 -79.413902
# 51     56        M4V   Central Toronto                Rathnelly  43.678395 -79.400822
# 52     57        M4V   Central Toronto               South Hill  43.677926 -79.405767
# 53     58        M4V   Central Toronto        Summerhill West\n  43.681678 -79.390504
# 54     59        M5V  Downtown Toronto                 CN Tower  43.642564 -79.387087
# 55     60        M5V  Downtown Toronto          Bathurst Quay\n  43.635790 -79.398329
# 56     62        M5V  Downtown Toronto      Harbourfront West\n  43.640080 -79.380150
# 57     63        M5V  Downtown Toronto         King and Spadina  43.645456 -79.394994
# 58     65        M5V  Downtown Toronto            South Niagara  43.644670 -79.409194
# 59     66        M4W  Downtown Toronto                 Rosedale  43.678356 -79.380746
# 60     68        M4X  Downtown Toronto              Cabbagetown  43.664473 -79.366986
# 61     69        M4X  Downtown Toronto           St. James Town  43.669403 -79.372704
# 62     70        M5X  Downtown Toronto     First Canadian Place  43.648768 -79.381692
# 63     71        M5X  Downtown Toronto         Underground city  43.770145 -79.374863
# 64     72        M4Y  Downtown Toronto     Church and Wellesley  43.665524 -79.383801

# %%
df_ungrp.drop(columns={'index'},inplace=True)
df_ungrp
# Out:
#    Postalcode           Borough             Neighborhood   Latitude  Longitude
# 0         M5A  Downtown Toronto             Harbourfront  43.640080 -79.380150
# 1         M7A  Downtown Toronto             Queen's Park  43.659659 -79.390340
# 2         M5B  Downtown Toronto                Ryerson\n  43.658469 -79.378993
# 3         M5B  Downtown Toronto        Garden District\n  43.656500 -79.377114
# 4         M5C  Downtown Toronto           St. James Town  43.669403 -79.372704
# 5         M4E      East Toronto              The Beaches  43.671024 -79.296712
# 6         M5E  Downtown Toronto              Berczy Park  43.647984 -79.375396
# 7         M6G  Downtown Toronto               Christie\n  43.664111 -79.418405
# 8         M5H  Downtown Toronto               Adelaide\n  43.650486 -79.379498
# 9         M5H  Downtown Toronto                   King\n  43.648949 -79.377754
# 10        M5H  Downtown Toronto               Richmond\n  43.812589 -79.263370
# 11        M6H      West Toronto       Dovercourt Village  43.665307 -79.432636
# 12        M6H      West Toronto               Dufferin\n  43.660202 -79.435719
# 13        M5J  Downtown Toronto      Harbourfront East\n  43.640080 -79.380150
# 14        M5J  Downtown Toronto          Toronto Islands  43.623054 -79.394316
# 15        M5J  Downtown Toronto            Union Station  43.644693 -79.380132
# 16        M6J      West Toronto          Little Portugal  43.647413 -79.431116
# 17        M6J      West Toronto                  Trinity  43.665302 -79.395252
# 18        M4K      East Toronto      The Danforth West\n  43.687017 -79.297511
# 19        M4K      East Toronto                Riverdale  43.665470 -79.352594
# 20        M5K  Downtown Toronto          Design Exchange  43.647741 -79.380115
# 21        M5K  Downtown Toronto  Toronto Dominion Centre  43.647377 -79.381372
# 22        M6K      West Toronto               Brockton\n  43.650917 -79.440022
# 23        M6K      West Toronto         Exhibition Place  43.633469 -79.417865
# 24        M6K      West Toronto         Parkdale Village  43.640495 -79.436897
# 25        M4L      East Toronto       The Beaches West\n  43.671024 -79.296712
# 26        M4L      East Toronto             India Bazaar  43.672223 -79.323503
# 27        M5L  Downtown Toronto           Commerce Court  43.648095 -79.379025
# 28        M4M      East Toronto        Studio District\n  43.649585 -79.390683
# 29        M4N   Central Toronto            Lawrence Park  43.729199 -79.403252
# 30        M5N   Central Toronto               Roselawn\n  43.710541 -79.401138
# 31        M4P   Central Toronto       Davisville North\n  43.704312 -79.388517
# 32        M5P   Central Toronto        Forest Hill North  43.693559 -79.413902
# 33        M6P      West Toronto                High Park  43.653867 -79.466864
# 34        M6P      West Toronto     The Junction South\n  43.665478 -79.470352
# 35        M5R   Central Toronto                The Annex  43.670338 -79.407117
# 36        M5R   Central Toronto                Yorkville  43.671386 -79.390168
# 37        M6R      West Toronto                 Parkdale  43.640495 -79.436897
# 38        M6R      West Toronto             Roncesvalles  43.651443 -79.451038
# 39        M4S   Central Toronto             Davisville\n  43.697936 -79.397291
# 40        M5S  Downtown Toronto                Harbord\n  43.661512 -79.414391
# 41        M5S  Downtown Toronto    University of Toronto  43.663462 -79.397760
# 42        M6S      West Toronto                Runnymede  43.651703 -79.475998
# 43        M6S      West Toronto                  Swansea  43.644940 -79.478313
# 44        M4T   Central Toronto               Moore Park  43.690388 -79.383297
# 45        M4T   Central Toronto        Summerhill East\n  43.681678 -79.390504
# 46        M5T  Downtown Toronto                Chinatown  43.652924 -79.398032
# 47        M5T  Downtown Toronto              Grange Park  43.652197 -79.392319
# 48        M5T  Downtown Toronto        Kensington Market  43.655214 -79.402260
# 49        M4V   Central Toronto                Deer Park  43.688090 -79.394093
# 50        M4V   Central Toronto         Forest Hill SE\n  43.693559 -79.413902
# 51        M4V   Central Toronto                Rathnelly  43.678395 -79.400822
# 52        M4V   Central Toronto               South Hill  43.677926 -79.405767
# 53        M4V   Central Toronto        Summerhill West\n  43.681678 -79.390504
# 54        M5V  Downtown Toronto                 CN Tower  43.642564 -79.387087
# 55        M5V  Downtown Toronto          Bathurst Quay\n  43.635790 -79.398329
# 56        M5V  Downtown Toronto      Harbourfront West\n  43.640080 -79.380150
# 57        M5V  Downtown Toronto         King and Spadina  43.645456 -79.394994
# 58        M5V  Downtown Toronto            South Niagara  43.644670 -79.409194
# 59        M4W  Downtown Toronto                 Rosedale  43.678356 -79.380746
# 60        M4X  Downtown Toronto              Cabbagetown  43.664473 -79.366986
# 61        M4X  Downtown Toronto           St. James Town  43.669403 -79.372704
# 62        M5X  Downtown Toronto     First Canadian Place  43.648768 -79.381692
# 63        M5X  Downtown Toronto         Underground city  43.770145 -79.374863
# 64        M4Y  Downtown Toronto     Church and Wellesley  43.665524 -79.383801

# %%
df_ungrp.to_csv("output.csv")

# %% [markdown]
# **Generating a map of Toronto**

# %%
map_toronto = folium.Map(location=[latitude, longitude], zoom_start=11)

for lat, lng, borough, neighborhood in zip(df_ungrp['Latitude'], df_ungrp['Longitude'], df_ungrp['Borough'], df_ungrp['Neighborhood']):
    label = '{}, {}'.format(neighborhood, borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_toronto)  
    
map_toronto
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# **Lets use FOURSQUARE API to explore the neighbourhood**

# %%
CLIENT_ID = '4QDVATW2MK21H2W30JDRMFCUOXUA4PG0CDTHQMRDBSOMNPW5' # your Foursquare ID
CLIENT_SECRET = 'OEYOBAVSHLA4HUOVDZPTTTWWNESFKD22KLN0ONOIIW12LSCI' # your Foursquare Secret
VERSION = '20180605' # Foursquare API version

print('Successfully Logged-In')
# Out:
# Successfully Logged-In

# %%
df_ungrp.loc[0]
neighborhood_latitude = np.float(df_ungrp.loc[0,['Latitude']].values)
neighborhood_longitude =  np.float(df_ungrp.loc[0,['Longitude']].values)

# %% [markdown]
# **Now, let's get the top 100 venues that are in Harbour Square Park within a radius of 500 meters**

# %% [markdown]
# *First, let's create the GET request URL. Name the URL url*

# %%
LIMIT = 100 # limit of number of venues returned by Foursquare API

radius = 500 # define radius

# create URL
url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
    CLIENT_ID, 
    CLIENT_SECRET, 
    VERSION, 
    neighborhood_latitude, 
    neighborhood_longitude, 
    radius, 
    LIMIT)
results = requests.get(url).json()

# %%
# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# %% [markdown]
# *Now let's clean the json and structure it into a pandas dataframe.*

# %%
venues = results['response']['groups'][0]['items']
    
nearby_venues = json_normalize(venues) # flatten JSON

# filter columns
filtered_columns = ['venue.name', 'venue.categories', 'venue.location.lat', 'venue.location.lng']
nearby_venues =nearby_venues.loc[:, filtered_columns]

# filter the category for each row
nearby_venues['venue.categories'] = nearby_venues.apply(get_category_type, axis=1)

# clean columns
nearby_venues.columns = [col.split(".")[-1] for col in nearby_venues.columns]

nearby_venues.head()
# Out:
# /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages/ipykernel_launcher.py:3: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   This is separate from the ipykernel package so we can avoid doing imports until
#                   name           categories        lat        lng
# 0  Harbour Square Park                 Park  43.639253 -79.378395
# 1         Lake Ontario                 Lake  43.638945 -79.379665
# 2         Harbourfront         Neighborhood  43.639526 -79.380688
# 3                 Miku  Japanese Restaurant  43.641374 -79.377531
# 4     Natrel Pond/Rink         Skating Rink  43.638431 -79.382528

# %%
print('{} venues were returned by Foursquare.'.format(nearby_venues.shape[0]))
# Out:
# 100 venues were returned by Foursquare.

# %% [markdown]
# ##### 2. Exploring the Neighborhoods in Toronto

# %%
def getNearbyVenues(names, latitudes, longitudes, radius=500):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        print(name)
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
            
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighborhood', 
                  'Neighborhood Latitude', 
                  'Neighborhood Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

# %%
toronto_venues = getNearbyVenues(names=df_ungrp['Neighborhood'],
                                   latitudes=df_ungrp['Latitude'],
                                   longitudes=df_ungrp['Longitude']
                                  )
print(toronto_venues.shape)
toronto_venues.head()
# Out:
# Harbourfront
# Queen's Park
# Ryerson
#
# Garden District
#
# St. James Town
# The Beaches
# Berczy Park
# Christie
#
# Adelaide
#
# King
#
# Richmond
#
# Dovercourt Village
# Dufferin
#
# Harbourfront East
#
# Toronto Islands
# Union Station
# Little Portugal
# Trinity
# The Danforth West
#
# Riverdale
# Design Exchange
# Toronto Dominion Centre
# Brockton
#
# Exhibition Place
# Parkdale Village
# The Beaches West
#
# India Bazaar
# Commerce Court
# Studio District
#
# Lawrence Park
# Roselawn
#
# Davisville North
#
# Forest Hill North
# High Park
# The Junction South
#
# The Annex
# Yorkville
# Parkdale
# Roncesvalles
# Davisville
#
# Harbord
#
# University of Toronto
# Runnymede
# Swansea
# Moore Park
# Summerhill East
#
# Chinatown
# Grange Park
# Kensington Market
# Deer Park
# Forest Hill SE
#
# Rathnelly
# South Hill
# Summerhill West
#
# CN Tower
# Bathurst Quay
#
# Harbourfront West
#
# King and Spadina
# South Niagara
# Rosedale
# Cabbagetown
# St. James Town
# First Canadian Place
# Underground city
# Church and Wellesley
# (3386, 7)
#    Neighborhood  Neighborhood Latitude  Neighborhood Longitude                Venue  Venue Latitude  Venue Longitude       Venue Category
# 0  Harbourfront               43.64008               -79.38015  Harbour Square Park       43.639253       -79.378395                 Park
# 1  Harbourfront               43.64008               -79.38015         Lake Ontario       43.638945       -79.379665                 Lake
# 2  Harbourfront               43.64008               -79.38015         Harbourfront       43.639526       -79.380688         Neighborhood
# 3  Harbourfront               43.64008               -79.38015                 Miku       43.641374       -79.377531  Japanese Restaurant
# 4  Harbourfront               43.64008               -79.38015     Natrel Pond/Rink       43.638431       -79.382528         Skating Rink

# %%
toronto_venues.groupby('Neighborhood').count()
# Out:
#                          Neighborhood Latitude  Neighborhood Longitude  Venue  Venue Latitude  Venue Longitude  Venue Category
# Neighborhood
# Adelaide\n                                 100                     100    100             100              100             100
# Bathurst Quay\n                             25                      25     25              25               25              25
# Berczy Park                                100                     100    100             100              100             100
# Brockton\n                                  22                      22     22              22               22              22
# CN Tower                                    58                      58     58              58               58              58
# Cabbagetown                                 46                      46     46              46               46              46
# Chinatown                                   58                      58     58              58               58              58
# Christie\n                                  58                      58     58              58               58              58
# Church and Wellesley                        78                      78     78              78               78              78
# Commerce Court                             100                     100    100             100              100             100
# Davisville\n                                46                      46     46              46               46              46
# Davisville North\n                          35                      35     35              35               35              35
# Deer Park                                   56                      56     56              56               56              56
# Design Exchange                            100                     100    100             100              100             100
# Dovercourt Village                           8                       8      8               8                8               8
# Dufferin\n                                  46                      46     46              46               46              46
# Exhibition Place                            36                      36     36              36               36              36
# First Canadian Place                       100                     100    100             100              100             100
# Forest Hill North                            5                       5      5               5                5               5
# Forest Hill SE\n                             5                       5      5               5                5               5
# Garden District\n                           62                      62     62              62               62              62
# Grange Park                                100                     100    100             100              100             100
# Harbord\n                                   75                      75     75              75               75              75
# Harbourfront                               100                     100    100             100              100             100
# Harbourfront East\n                        100                     100    100             100              100             100
# Harbourfront West\n                        100                     100    100             100              100             100
# High Park                                   12                      12     12              12               12              12
# India Bazaar                                37                      37     37              37               37              37
# Kensington Market                           86                      86     86              86               86              86
# King\n                                     100                     100    100             100              100             100
# King and Spadina                            67                      67     67              67               67              67
# Lawrence Park                               53                      53     53              53               53              53
# Little Portugal                             37                      37     37              37               37              37
# Moore Park                                   3                       3      3               3                3               3
# Parkdale                                    45                      45     45              45               45              45
# Parkdale Village                            45                      45     45              45               45              45
# Queen's Park                                78                      78     78              78               78              78
# Rathnelly                                   18                      18     18              18               18              18
# Richmond\n                                   2                       2      2               2                2               2
# Riverdale                                   31                      31     31              31               31              31
# Roncesvalles                                38                      38     38              38               38              38
# Rosedale                                     5                       5      5               5                5               5
# Roselawn\n                                  59                      59     59              59               59              59
# Runnymede                                   39                      39     39              39               39              39
# Ryerson\n                                  100                     100    100             100              100             100
# South Hill                                  28                      28     28              28               28              28
# South Niagara                               53                      53     53              53               53              53
# St. James Town                              62                      62     62              62               62              62
# Studio District\n                          100                     100    100             100              100             100
# Summerhill East\n                           40                      40     40              40               40              40
# Summerhill West\n                           40                      40     40              40               40              40
# Swansea                                      7                       7      7               7                7               7
# The Annex                                   46                      46     46              46               46              46
# The Beaches                                 49                      49     49              49               49              49
# The Beaches West\n                          49                      49     49              49               49              49
# The Danforth West\n                         34                      34     34              34               34              34
# The Junction South\n                        59                      59     59              59               59              59
# Toronto Dominion Centre                    100                     100    100             100              100             100
# Toronto Islands                              4                       4      4               4                4               4
# Trinity                                     43                      43     43              43               43              43
# Underground city                            14                      14     14              14               14              14
# Union Station                               53                      53     53              53               53              53
# University of Toronto                       31                      31     31              31               31              31
# Yorkville                                  100                     100    100             100              100             100

# %%
print('There are {} uniques categories.'.format(len(toronto_venues['Venue Category'].unique())))
# Out:
# There are 288 uniques categories.

# %% [markdown]
# ##### 3. Analyzing Each Neighborhood

# %%
# one hot encoding
toronto_onehot = pd.get_dummies(toronto_venues[['Venue Category']], prefix="", prefix_sep="")

# add neighborhood column back to dataframe
toronto_onehot['Neighborhood'] = toronto_venues['Neighborhood'] 

# move neighborhood column to the first column
fixed_columns = [toronto_onehot.columns[-1]] + list(toronto_onehot.columns[:-1])
toronto_onehot = toronto_onehot[fixed_columns]

toronto_onehot.shape
# Out:
# (3386, 288)

# %%
toronto_grouped = toronto_onehot.groupby('Neighborhood').mean().reset_index()
toronto_grouped.shape
# Out:
# (64, 288)

# %% [markdown]
# **Lets Check top venues**

# %%
Top_venues = 5
for hood in toronto_grouped['Neighborhood']:
    print("----"+hood+"----")
    temp = toronto_grouped[toronto_grouped['Neighborhood'] == hood].T.reset_index()
    temp.columns = ['venue','freq']
    temp = temp.iloc[1:]
    temp['freq'] = temp['freq'].astype(float)
    temp = temp.round({'freq': 2})
    print(temp.sort_values('freq', ascending=False).reset_index(drop=True).head(Top_venues))
    print('\n')
# Out:
# ----Adelaide
# ----
#                  venue  freq
# 0          Coffee Shop  0.06
# 1                 Café  0.06
# 2  American Restaurant  0.04
# 3                  Gym  0.04
# 4  Japanese Restaurant  0.04
#
#
# ----Bathurst Quay
# ----
#          venue  freq
# 0  Coffee Shop  0.16
# 1         Café  0.12
# 2         Park  0.08
# 3        Diner  0.04
# 4       Tunnel  0.04
#
#
# ----Berczy Park----
#                 venue  freq
# 0         Coffee Shop  0.09
# 1                Café  0.06
# 2          Restaurant  0.05
# 3               Hotel  0.04
# 4  Italian Restaurant  0.04
#
#
# ----Brockton
# ----
#                    venue  freq
# 0                    Bar  0.14
# 1            Coffee Shop  0.09
# 2                   Café  0.09
# 3                   Park  0.09
# 4  Vietnamese Restaurant  0.09
#
#
# ----CN Tower----
#             venue  freq
# 0           Hotel  0.10
# 1     Pizza Place  0.07
# 2     Coffee Shop  0.07
# 3  Scenic Lookout  0.05
# 4             Gym  0.03
#
#
# ----Cabbagetown----
#          venue  freq
# 0  Coffee Shop  0.07
# 1         Café  0.07
# 2   Restaurant  0.07
# 3          Pub  0.04
# 4    Gastropub  0.04
#
#
# ----Chinatown----
#                            venue  freq
# 0                   Dessert Shop  0.07
# 1                           Café  0.07
# 2             Mexican Restaurant  0.05
# 3                    Coffee Shop  0.05
# 4  Vegetarian / Vegan Restaurant  0.03
#
#
# ----Christie
# ----
#                venue  freq
# 0  Korean Restaurant  0.22
# 1        Coffee Shop  0.05
# 2               Café  0.03
# 3     Ice Cream Shop  0.03
# 4       Dessert Shop  0.03
#
#
# ----Church and Wellesley----
#                  venue  freq
# 0     Sushi Restaurant  0.08
# 1          Coffee Shop  0.08
# 2  Japanese Restaurant  0.06
# 3           Restaurant  0.04
# 4        Grocery Store  0.04
#
#
# ----Commerce Court----
#                 venue  freq
# 0         Coffee Shop  0.11
# 1          Restaurant  0.08
# 2               Hotel  0.06
# 3                Café  0.06
# 4  Italian Restaurant  0.05
#
#
# ----Davisville
# ----
#                 venue  freq
# 0    Sushi Restaurant  0.09
# 1  Italian Restaurant  0.09
# 2         Coffee Shop  0.07
# 3   Convenience Store  0.04
# 4                 Gym  0.04
#
#
# ----Davisville North
# ----
#               venue  freq
# 0       Pizza Place  0.09
# 1    Sandwich Place  0.09
# 2      Dessert Shop  0.09
# 3  Sushi Restaurant  0.06
# 4              Café  0.06
#
#
# ----Deer Park----
#                 venue  freq
# 0         Coffee Shop  0.11
# 1  Italian Restaurant  0.07
# 2    Sushi Restaurant  0.07
# 3                Café  0.05
# 4       Grocery Store  0.05
#
#
# ----Design Exchange----
#          venue  freq
# 0  Coffee Shop  0.14
# 1         Café  0.07
# 2   Restaurant  0.06
# 3        Hotel  0.05
# 4          Gym  0.04
#
#
# ----Dovercourt Village----
#          venue  freq
# 0         Café  0.25
# 1  Coffee Shop  0.12
# 2         Park  0.12
# 3  Pizza Place  0.12
# 4          Bar  0.12
#
#
# ----Dufferin
# ----
#             venue  freq
# 0             Bar  0.11
# 1          Bakery  0.09
# 2     Coffee Shop  0.07
# 3            Café  0.07
# 4  Sandwich Place  0.04
#
#
# ----Exhibition Place----
#                  venue  freq
# 0           Theme Park  0.11
# 1       Soccer Stadium  0.08
# 2  Arts & Crafts Store  0.08
# 3        Poutine Place  0.06
# 4          Coffee Shop  0.06
#
#
# ----First Canadian Place----
#          venue  freq
# 0  Coffee Shop  0.10
# 1         Café  0.07
# 2        Hotel  0.07
# 3   Restaurant  0.05
# 4          Gym  0.04
#
#
# ----Forest Hill North----
#                     venue  freq
# 0              Playground   0.2
# 1  Furniture / Home Store   0.2
# 2                    Bank   0.2
# 3            Home Service   0.2
# 4                    Park   0.2
#
#
# ----Forest Hill SE
# ----
#                     venue  freq
# 0              Playground   0.2
# 1  Furniture / Home Store   0.2
# 2                    Bank   0.2
# 3            Home Service   0.2
# 4                    Park   0.2
#
#
# ----Garden District
# ----
#             venue  freq
# 0  Clothing Store  0.08
# 1      Restaurant  0.08
# 2     Coffee Shop  0.05
# 3           Hotel  0.05
# 4  Cosmetics Shop  0.05
#
#
# ----Grange Park----
#                venue  freq
# 0        Coffee Shop  0.08
# 1               Café  0.04
# 2  French Restaurant  0.03
# 3        Art Gallery  0.03
# 4     Clothing Store  0.03
#
#
# ----Harbord
# ----
#                venue  freq
# 0  Korean Restaurant  0.20
# 1        Coffee Shop  0.04
# 2               Park  0.04
# 3      Grocery Store  0.04
# 4     Sandwich Place  0.04
#
#
# ----Harbourfront----
#                 venue  freq
# 0         Coffee Shop  0.15
# 1                Café  0.05
# 2          Restaurant  0.04
# 3               Hotel  0.04
# 4  Italian Restaurant  0.03
#
#
# ----Harbourfront East
# ----
#                 venue  freq
# 0         Coffee Shop  0.15
# 1                Café  0.05
# 2          Restaurant  0.04
# 3               Hotel  0.04
# 4  Italian Restaurant  0.03
#
#
# ----Harbourfront West
# ----
#                 venue  freq
# 0         Coffee Shop  0.15
# 1                Café  0.05
# 2          Restaurant  0.04
# 3               Hotel  0.04
# 4  Italian Restaurant  0.03
#
#
# ----High Park----
#                  venue  freq
# 0    Convenience Store  0.25
# 1  Sporting Goods Shop  0.08
# 2   Mexican Restaurant  0.08
# 3       Mattress Store  0.08
# 4                 Park  0.08
#
#
# ----India Bazaar----
#                venue  freq
# 0  Indian Restaurant  0.22
# 1      Grocery Store  0.08
# 2               Café  0.08
# 3      Women's Store  0.03
# 4  Convenience Store  0.03
#
#
# ----Kensington Market----
#                    venue  freq
# 0                   Café  0.08
# 1            Coffee Shop  0.06
# 2                    Bar  0.06
# 3     Mexican Restaurant  0.05
# 4  Vietnamese Restaurant  0.03
#
#
# ----King
# ----
#                  venue  freq
# 0          Coffee Shop  0.08
# 1           Restaurant  0.06
# 2                Hotel  0.05
# 3                 Café  0.05
# 4  American Restaurant  0.04
#
#
# ----King and Spadina----
#                 venue  freq
# 0         Coffee Shop  0.07
# 1          Restaurant  0.06
# 2  Italian Restaurant  0.06
# 3                 Gym  0.04
# 4            Beer Bar  0.04
#
#
# ----Lawrence Park----
#                   venue  freq
# 0      Sushi Restaurant  0.08
# 1    Italian Restaurant  0.08
# 2           Coffee Shop  0.06
# 3                Bakery  0.06
# 4  Fast Food Restaurant  0.04
#
#
# ----Little Portugal----
#                venue  freq
# 0                Bar  0.14
# 1               Café  0.11
# 2        Coffee Shop  0.08
# 3  Korean Restaurant  0.05
# 4         Restaurant  0.05
#
#
# ----Moore Park----
#                venue  freq
# 0  Convenience Store  0.33
# 1               Park  0.33
# 2                Gym  0.33
# 3        Yoga Studio  0.00
# 4       Night Market  0.00
#
#
# ----Parkdale----
#                 venue  freq
# 0  Tibetan Restaurant  0.07
# 1              Bakery  0.04
# 2            Pharmacy  0.04
# 3               Diner  0.04
# 4          Restaurant  0.04
#
#
# ----Parkdale Village----
#                 venue  freq
# 0  Tibetan Restaurant  0.07
# 1              Bakery  0.04
# 2            Pharmacy  0.04
# 3               Diner  0.04
# 4          Restaurant  0.04
#
#
# ----Queen's Park----
#                 venue  freq
# 0         Coffee Shop  0.26
# 1                Café  0.10
# 2  Italian Restaurant  0.06
# 3      Sandwich Place  0.06
# 4          Restaurant  0.03
#
#
# ----Rathnelly----
#                 venue  freq
# 0  Italian Restaurant  0.11
# 1   French Restaurant  0.11
# 2                Park  0.11
# 3  Mexican Restaurant  0.11
# 4                Café  0.06
#
#
# ----Richmond
# ----
#                      venue  freq
# 0           Ice Cream Shop   0.5
# 1               Beer Store   0.5
# 2              Yoga Studio   0.0
# 3               Nail Salon   0.0
# 4  North Indian Restaurant   0.0
#
#
# ----Riverdale----
#                    venue  freq
# 0  Vietnamese Restaurant  0.16
# 1     Chinese Restaurant  0.13
# 2                 Bakery  0.10
# 3   Fast Food Restaurant  0.06
# 4     Light Rail Station  0.06
#
#
# ----Roncesvalles----
#           venue  freq
# 0          Café  0.08
# 1    Restaurant  0.08
# 2  Gourmet Shop  0.05
# 3     Gift Shop  0.05
# 4     Bookstore  0.05
#
#
# ----Rosedale----
#                  venue  freq
# 0                 Park   0.4
# 1           Playground   0.2
# 2  Japanese Restaurant   0.2
# 3           Bike Trail   0.2
# 4        Moving Target   0.0
#
#
# ----Roselawn
# ----
#                   venue  freq
# 0           Coffee Shop  0.08
# 1            Restaurant  0.05
# 2    Italian Restaurant  0.05
# 3  Fast Food Restaurant  0.05
# 4           Yoga Studio  0.03
#
#
# ----Runnymede----
#          venue  freq
# 0         Café  0.10
# 1  Coffee Shop  0.10
# 2       Bakery  0.08
# 3  Pizza Place  0.05
# 4         Bank  0.05
#
#
# ----Ryerson
# ----
#               venue  freq
# 0       Coffee Shop  0.12
# 1    Clothing Store  0.05
# 2              Café  0.04
# 3  Ramen Restaurant  0.03
# 4      Burger Joint  0.03
#
#
# ----South Hill----
#             venue  freq
# 0  Sandwich Place  0.11
# 1            Café  0.07
# 2     Coffee Shop  0.07
# 3  History Museum  0.07
# 4    Liquor Store  0.04
#
#
# ----South Niagara----
#                     venue  freq
# 0             Pizza Place  0.06
# 1                  Bakery  0.06
# 2            Dessert Shop  0.06
# 3             Coffee Shop  0.04
# 4  Furniture / Home Store  0.04
#
#
# ----St. James Town----
#            venue  freq
# 0    Coffee Shop  0.16
# 1    Pizza Place  0.10
# 2           Café  0.06
# 3  Grocery Store  0.06
# 4     Playground  0.03
#
#
# ----Studio District
# ----
#                  venue  freq
# 0          Coffee Shop  0.06
# 1  Japanese Restaurant  0.03
# 2       Cosmetics Shop  0.03
# 3       Clothing Store  0.03
# 4                 Café  0.03
#
#
# ----Summerhill East
# ----
#                 venue  freq
# 0  Italian Restaurant  0.08
# 1                Café  0.08
# 2         Coffee Shop  0.05
# 3                 Spa  0.05
# 4    Sushi Restaurant  0.05
#
#
# ----Summerhill West
# ----
#                 venue  freq
# 0  Italian Restaurant  0.08
# 1                Café  0.08
# 2         Coffee Shop  0.05
# 3                 Spa  0.05
# 4    Sushi Restaurant  0.05
#
#
# ----Swansea----
#                         venue  freq
# 0                        Park  0.29
# 1                    Bus Line  0.14
# 2                Skating Rink  0.14
# 3                 Social Club  0.14
# 4  Construction & Landscaping  0.14
#
#
# ----The Annex----
#                venue  freq
# 0        Pizza Place  0.11
# 1        Coffee Shop  0.07
# 2               Park  0.04
# 3    Thai Restaurant  0.04
# 4  Indian Restaurant  0.04
#
#
# ----The Beaches----
#                  venue  freq
# 0                Beach  0.06
# 1             Tea Room  0.04
# 2                  Pub  0.04
# 3       Breakfast Spot  0.04
# 4  Japanese Restaurant  0.04
#
#
# ----The Beaches West
# ----
#                  venue  freq
# 0                Beach  0.06
# 1             Tea Room  0.04
# 2                  Pub  0.04
# 3       Breakfast Spot  0.04
# 4  Japanese Restaurant  0.04
#
#
# ----The Danforth West
# ----
#             venue  freq
# 0     Coffee Shop  0.12
# 1    Skating Rink  0.06
# 2  Ice Cream Shop  0.06
# 3        Bus Line  0.06
# 4    Burger Joint  0.03
#
#
# ----The Junction South
# ----
#                 venue  freq
# 0  Italian Restaurant  0.07
# 1         Coffee Shop  0.07
# 2                Café  0.05
# 3                 Bar  0.05
# 4     Thai Restaurant  0.05
#
#
# ----Toronto Dominion Centre----
#                  venue  freq
# 0          Coffee Shop  0.12
# 1                Hotel  0.08
# 2                 Café  0.07
# 3  American Restaurant  0.04
# 4  Japanese Restaurant  0.04
#
#
# ----Toronto Islands----
#              venue  freq
# 0             Park  0.25
# 1  Harbor / Marina  0.25
# 2             Café  0.25
# 3      Music Venue  0.25
# 4      Yoga Studio  0.00
#
#
# ----Trinity----
#             venue  freq
# 0     Coffee Shop  0.09
# 1            Café  0.07
# 2        Boutique  0.05
# 3  Clothing Store  0.05
# 4      Restaurant  0.05
#
#
# ----Underground city----
#                  venue  freq
# 0  Sporting Goods Shop  0.07
# 1       Breakfast Spot  0.07
# 2          Fish Market  0.07
# 3   Chinese Restaurant  0.07
# 4       Sandwich Place  0.07
#
#
# ----Union Station----
#                  venue  freq
# 0          Coffee Shop  0.13
# 1                 Café  0.08
# 2                Hotel  0.06
# 3  Japanese Restaurant  0.06
# 4       Breakfast Spot  0.04
#
#
# ----University of Toronto----
#                  venue  freq
# 0                 Café  0.16
# 1   Italian Restaurant  0.06
# 2                 Park  0.06
# 3  Japanese Restaurant  0.06
# 4            Bookstore  0.06
#
#
# ----Yorkville----
#                 venue  freq
# 0            Boutique  0.05
# 1  Italian Restaurant  0.05
# 2                 Spa  0.04
# 3          Restaurant  0.04
# 4         Coffee Shop  0.04

# %%
def return_most_common_venues(row, Top_venues):
    row_categories = row.iloc[1:]
    row_categories_sorted = row_categories.sort_values(ascending=False)
    
    return row_categories_sorted.index.values[0:Top_venues]

# %%
Top_venues = 10

indicators = ['st', 'nd', 'rd']

# create columns according to number of top venues
columns = ['Neighborhood']
for ind in np.arange(Top_venues):
    try:
        columns.append('{}{} Popular Venues'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Popular Venues'.format(ind+1))

# create a new dataframe
neighborhoods_venues_sorted = pd.DataFrame(columns=columns)
neighborhoods_venues_sorted['Neighborhood'] = toronto_grouped['Neighborhood']

for ind in np.arange(toronto_grouped.shape[0]):
    neighborhoods_venues_sorted.iloc[ind, 1:] = return_most_common_venues(toronto_grouped.iloc[ind, :], Top_venues)

neighborhoods_venues_sorted
# Out:
#                Neighborhood     1st Popular Venues      2nd Popular Venues             3rd Popular Venues          4th Popular Venues             5th Popular Venues     6th Popular Venues             7th Popular Venues      8th Popular Venues      9th Popular Venues          10th Popular Venues
# 0                Adelaide\n                   Café             Coffee Shop            American Restaurant         Japanese Restaurant                            Gym             Restaurant                      Gastropub          Cosmetics Shop      Seafood Restaurant                     Tea Room
# 1           Bathurst Quay\n            Coffee Shop                    Café                           Park             Harbor / Marina       Bike Rental / Bike Share       Ramen Restaurant                         Garden           Grocery Store     Japanese Restaurant                         Bank
# 2               Berczy Park            Coffee Shop                    Café                     Restaurant                       Hotel             Italian Restaurant    Japanese Restaurant                            Gym      Seafood Restaurant            Cocktail Bar                    Gastropub
# 3                Brockton\n                    Bar                    Café          Vietnamese Restaurant                        Park                    Coffee Shop      French Restaurant                       Dive Bar             Music Venue               Gastropub            Korean Restaurant
# 4                  CN Tower                  Hotel             Coffee Shop                    Pizza Place              Scenic Lookout                 Ice Cream Shop                Theater                       Aquarium                     Gym        Baseball Stadium               Sandwich Place
# 5               Cabbagetown            Coffee Shop              Restaurant                           Café         Japanese Restaurant                            Pub              Gastropub                          Diner              Beer Store                  Bakery            Indian Restaurant
# 6                 Chinatown                   Café            Dessert Shop                    Coffee Shop          Mexican Restaurant                         Bakery  Vietnamese Restaurant  Vegetarian / Vegan Restaurant          Clothing Store                     Bar             Ramen Restaurant
# 7                Christie\n      Korean Restaurant             Coffee Shop             Mexican Restaurant               Grocery Store                            Pub           Cocktail Bar            Japanese Restaurant       Indian Restaurant               Gift Shop               Sandwich Place
# 8      Church and Wellesley       Sushi Restaurant             Coffee Shop            Japanese Restaurant               Grocery Store                     Restaurant                  Hotel                   Burger Joint                    Café                   Diner                    Gastropub
# 9            Commerce Court            Coffee Shop              Restaurant                          Hotel                        Café             Italian Restaurant    Japanese Restaurant            American Restaurant                     Gym      Seafood Restaurant                Deli / Bodega
# 10             Davisville\n       Sushi Restaurant      Italian Restaurant                    Coffee Shop                         Gym                            Pub      Convenience Store                          Trail                   Hotel      Falafel Restaurant               Sandwich Place
# 11       Davisville North\n            Pizza Place          Sandwich Place                   Dessert Shop            Sushi Restaurant                            Gym                   Café             Italian Restaurant             Coffee Shop              Restaurant                          Bar
# 12                Deer Park            Coffee Shop        Sushi Restaurant             Italian Restaurant                        Café                  Grocery Store        Thai Restaurant                     Restaurant                    Bank          Sandwich Place                          Gym
# 13          Design Exchange            Coffee Shop                    Café                     Restaurant                       Hotel            American Restaurant                    Gym             Seafood Restaurant           Deli / Bodega                Tea Room                       Bakery
# 14       Dovercourt Village                   Café             Pizza Place                           Park        Brazilian Restaurant                            Bar             Restaurant                    Coffee Shop            Dessert Shop       Electronics Store                  Flower Shop
# 15               Dufferin\n                    Bar                  Bakery                           Café                 Coffee Shop                 Sandwich Place             Restaurant                       Beer Bar              Beer Store            Cocktail Bar           Mexican Restaurant
# 16         Exhibition Place             Theme Park          Soccer Stadium            Arts & Crafts Store               Poutine Place                    Coffee Shop     Athletics & Sports   Theme Park Ride / Attraction           Moving Target        Storage Facility                    Nightclub
# 17     First Canadian Place            Coffee Shop                   Hotel                           Café                  Restaurant                            Gym    Japanese Restaurant            American Restaurant             Salad Place        Asian Restaurant           Seafood Restaurant
# 18        Forest Hill North             Playground  Furniture / Home Store                           Bank                        Park                   Home Service            Flea Market                    Fish Market       Fish & Chips Shop     Filipino Restaurant         Fast Food Restaurant
# 19         Forest Hill SE\n             Playground  Furniture / Home Store                           Bank                        Park                   Home Service            Flea Market                    Fish Market       Fish & Chips Shop     Filipino Restaurant         Fast Food Restaurant
# 20        Garden District\n             Restaurant          Clothing Store                          Hotel                 Coffee Shop                 Cosmetics Shop              Bookstore                       Tea Room     Japanese Restaurant          Sandwich Place                         Café
# 21              Grange Park            Coffee Shop                    Café                 Ice Cream Shop         Japanese Restaurant            Arts & Crafts Store            Art Gallery             Chinese Restaurant       French Restaurant          Clothing Store               Sandwich Place
# 22                Harbord\n      Korean Restaurant                    Café                  Grocery Store              Sandwich Place                           Park            Coffee Shop            Japanese Restaurant      Mexican Restaurant          Ice Cream Shop         Fast Food Restaurant
# 23             Harbourfront            Coffee Shop                    Café                          Hotel                  Restaurant             Italian Restaurant             Sports Bar               Sushi Restaurant             Music Venue                     Gym                         Bank
# 24      Harbourfront East\n            Coffee Shop                    Café                          Hotel                  Restaurant             Italian Restaurant             Sports Bar               Sushi Restaurant             Music Venue                     Gym                         Bank
# 25      Harbourfront West\n            Coffee Shop                    Café                          Hotel                  Restaurant             Italian Restaurant             Sports Bar               Sushi Restaurant             Music Venue                     Gym                         Bank
# 26                High Park      Convenience Store               Pet Store                           Park         Sporting Goods Shop                 Mattress Store                    Gym                            Pub      Mexican Restaurant                    Pool                  Pizza Place
# 27             India Bazaar      Indian Restaurant           Grocery Store                           Café               Women's Store                       Platform                Brewery                   Burger Joint                Bus Line             Snack Place               Shopping Plaza
# 28        Kensington Market                   Café             Coffee Shop                            Bar          Mexican Restaurant  Vegetarian / Vegan Restaurant                 Bakery          Vietnamese Restaurant               Nightclub            Dessert Shop                Grocery Store
# 29                   King\n            Coffee Shop              Restaurant                          Hotel                        Café                            Gym    Japanese Restaurant                      Gastropub      Seafood Restaurant      Italian Restaurant          American Restaurant
# 30         King and Spadina            Coffee Shop      Italian Restaurant                     Restaurant                    Beer Bar                            Gym                  Hotel                 Sandwich Place                     Bar       French Restaurant            Indian Restaurant
# 31            Lawrence Park       Sushi Restaurant      Italian Restaurant                         Bakery                 Coffee Shop                    Pizza Place                    Pub           Fast Food Restaurant        Asian Restaurant                    Bank              Bubble Tea Shop
# 32          Little Portugal                    Bar                    Café                    Coffee Shop           Korean Restaurant                   Cocktail Bar             Restaurant                         Bakery           Grocery Store                Boutique                    Jazz Club
# 33               Moore Park                   Park                     Gym              Convenience Store               Women's Store              Electronics Store   Ethiopian Restaurant                    Event Space      Falafel Restaurant                    Farm               Farmers Market
# 34                 Parkdale     Tibetan Restaurant       Indian Restaurant                          Diner                         Bar                           Café                 Bakery                     Restaurant                Pharmacy                Boutique           Chinese Restaurant
# 35         Parkdale Village     Tibetan Restaurant       Indian Restaurant                          Diner                         Bar                           Café                 Bakery                     Restaurant                Pharmacy                Boutique           Chinese Restaurant
# 36             Queen's Park            Coffee Shop                    Café             Italian Restaurant              Sandwich Place             Chinese Restaurant        Bubble Tea Shop                Thai Restaurant     Japanese Restaurant          Ice Cream Shop            French Restaurant
# 37                Rathnelly      French Restaurant                    Park             Mexican Restaurant          Italian Restaurant                    Pizza Place              BBQ Joint                           Café            Liquor Store          Sandwich Place                  Coffee Shop
# 38               Richmond\n         Ice Cream Shop              Beer Store                  Women's Store         Filipino Restaurant           Ethiopian Restaurant            Event Space             Falafel Restaurant                    Farm          Farmers Market         Fast Food Restaurant
# 39                Riverdale  Vietnamese Restaurant      Chinese Restaurant                         Bakery          Light Rail Station           Fast Food Restaurant            Coffee Shop                    Bridal Shop        Asian Restaurant                    Café               Breakfast Spot
# 40             Roncesvalles             Restaurant                    Café                   Gourmet Shop                   Gift Shop                      Bookstore              Gastropub                    Gas Station                     Pub        Sushi Restaurant                      Brewery
# 41                 Rosedale                   Park              Bike Trail            Japanese Restaurant                  Playground                    Flea Market            Fish Market              Fish & Chips Shop     Filipino Restaurant             Flower Shop  Eastern European Restaurant
# 42               Roselawn\n            Coffee Shop    Fast Food Restaurant             Italian Restaurant                  Restaurant                      Bookstore                   Park             Mexican Restaurant             Yoga Studio           Movie Theater                  Pizza Place
# 43                Runnymede                   Café             Coffee Shop                         Bakery                        Bank                    Pizza Place               Tea Room             Italian Restaurant               Gastropub                     Pub    Latin American Restaurant
# 44                Ryerson\n            Coffee Shop          Clothing Store                           Café                Burger Joint                     Restaurant       Ramen Restaurant             Italian Restaurant     Japanese Restaurant                   Diner    Middle Eastern Restaurant
# 45               South Hill         Sandwich Place          History Museum                           Café                 Coffee Shop                           Park                 Castle                            Pub             Pizza Place                Pharmacy                   Donut Shop
# 46            South Niagara            Pizza Place            Dessert Shop                         Bakery                 Yoga Studio                            Spa            Coffee Shop                           Café  Furniture / Home Store     American Restaurant                    Pet Store
# 47           St. James Town            Coffee Shop             Pizza Place                  Grocery Store                        Café                       Pharmacy         Breakfast Spot           Caribbean Restaurant          Sandwich Place              Restaurant                   Playground
# 48        Studio District\n            Coffee Shop                    Café  Vegetarian / Vegan Restaurant              Clothing Store                 Cosmetics Shop    Japanese Restaurant                          Hotel       Indian Restaurant              Shoe Store                   Restaurant
# 49        Summerhill East\n     Italian Restaurant                    Café               Sushi Restaurant                         Spa                    Coffee Shop             Kids Store              French Restaurant               Juice Bar            Liquor Store                       Bakery
# 50        Summerhill West\n     Italian Restaurant                    Café               Sushi Restaurant                         Spa                    Coffee Shop             Kids Store              French Restaurant               Juice Bar            Liquor Store                       Bakery
# 51                  Swansea                   Park                Bus Line                    Social Club  Construction & Landscaping                     Restaurant           Skating Rink                  Women's Store      Falafel Restaurant     Egyptian Restaurant            Electronics Store
# 52                The Annex            Pizza Place             Coffee Shop                         Bistro                        Park              Indian Restaurant         Ice Cream Shop                Thai Restaurant           Grocery Store              Donut Shop    Middle Eastern Restaurant
# 53              The Beaches                  Beach                     Pub            Japanese Restaurant                    Tea Room                            Bar                 Bakery                 Breakfast Spot             Pizza Place                    Park                 Liquor Store
# 54       The Beaches West\n                  Beach                     Pub            Japanese Restaurant                    Tea Room                            Bar                 Bakery                 Breakfast Spot             Pizza Place                    Park                 Liquor Store
# 55      The Danforth West\n            Coffee Shop            Skating Rink                       Bus Line              Ice Cream Shop            Fried Chicken Joint           Intersection                  Metro Station        Sushi Restaurant  Furniture / Home Store            French Restaurant
# 56     The Junction South\n            Coffee Shop      Italian Restaurant                Thai Restaurant                        Café                            Bar             Nail Salon                   Antique Shop     Arts & Crafts Store      Mexican Restaurant                     Bus Stop
# 57  Toronto Dominion Centre            Coffee Shop                   Hotel                           Café                  Restaurant            Japanese Restaurant    American Restaurant                  Deli / Bodega      Seafood Restaurant        Asian Restaurant                   Steakhouse
# 58          Toronto Islands                   Park                    Café                Harbor / Marina                 Music Venue                 Farmers Market      Electronics Store           Ethiopian Restaurant             Event Space      Falafel Restaurant                         Farm
# 59                  Trinity            Coffee Shop                    Café                 Clothing Store                  Restaurant                       Boutique                   Park                         Museum             Music Store     Japanese Restaurant                Jewelry Store
# 60         Underground city        Bubble Tea Shop                    Bank                    Fish Market         Sporting Goods Shop                 Breakfast Spot   Fast Food Restaurant             Chinese Restaurant             Gas Station          Sandwich Place               Clothing Store
# 61            Union Station            Coffee Shop                    Café                          Hotel         Japanese Restaurant            Sporting Goods Shop          Deli / Bodega                     Restaurant          Breakfast Spot             Salad Place                  Supermarket
# 62    University of Toronto                   Café                    Park                      Bookstore         Japanese Restaurant             Italian Restaurant                  Hotel        Comfort Food Restaurant            Noodle House                  Museum            French Restaurant
# 63                Yorkville               Boutique      Italian Restaurant                           Café              Clothing Store                    Coffee Shop             Restaurant                            Spa           Women's Store        Sushi Restaurant            French Restaurant

# %%
neighborhoods_venues_sorted.to_csv("output2.csv")

# %% [markdown]
# ##### 4. Cluster Neighborhoods using K-Mean

# %%
# set number of clusters
kclusters = 5

toronto_grouped_clustering = toronto_grouped.drop('Neighborhood',1)
#print(toronto_grouped_clustering)
#print(toronto_grouped)
# run k-means clustering
kmeans = KMeans(init = "k-means++", n_clusters=kclusters, random_state=0).fit(toronto_grouped_clustering)

# check cluster labels generated for each row in the dataframe
labels = kmeans.labels_[0:66]

# %%
toronto_merged = df_ungrp
print(toronto_merged.shape)
labels = np.append(labels,labels[0])
print(labels.shape)
# add clustering labels
toronto_merged['Cluster Labels'] = labels.tolist()

# merge toronto_grouped with toronto_data to add latitude/longitude for each neighborhood
toronto_merged = toronto_merged.join(neighborhoods_venues_sorted.set_index('Neighborhood'), on='Neighborhood')

toronto_merged.head() # check the last columns!
# Out:
# (65, 5)
# (65,)
#   Postalcode           Borough       Neighborhood   Latitude  Longitude  Cluster Labels 1st Popular Venues 2nd Popular Venues  3rd Popular Venues 4th Popular Venues  5th Popular Venues 6th Popular Venues    7th Popular Venues   8th Popular Venues 9th Popular Venues        10th Popular Venues
# 0        M5A  Downtown Toronto       Harbourfront  43.640080 -79.380150               4        Coffee Shop               Café               Hotel         Restaurant  Italian Restaurant         Sports Bar      Sushi Restaurant          Music Venue                Gym                       Bank
# 1        M7A  Downtown Toronto       Queen's Park  43.659659 -79.390340               4        Coffee Shop               Café  Italian Restaurant     Sandwich Place  Chinese Restaurant    Bubble Tea Shop       Thai Restaurant  Japanese Restaurant     Ice Cream Shop          French Restaurant
# 2        M5B  Downtown Toronto          Ryerson\n  43.658469 -79.378993               4        Coffee Shop     Clothing Store                Café       Burger Joint          Restaurant   Ramen Restaurant    Italian Restaurant  Japanese Restaurant              Diner  Middle Eastern Restaurant
# 3        M5B  Downtown Toronto  Garden District\n  43.656500 -79.377114               4         Restaurant     Clothing Store               Hotel        Coffee Shop      Cosmetics Shop          Bookstore              Tea Room  Japanese Restaurant     Sandwich Place                       Café
# 4        M5C  Downtown Toronto     St. James Town  43.669403 -79.372704               4        Coffee Shop        Pizza Place       Grocery Store               Café            Pharmacy     Breakfast Spot  Caribbean Restaurant       Sandwich Place         Restaurant                 Playground

# %%
# create map
map_clusters = folium.Map(location=[latitude, longitude], zoom_start=11)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i+x+(i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(toronto_merged['Latitude'], toronto_merged['Longitude'], toronto_merged['Neighborhood'], toronto_merged['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ##### 5. Examine Clusters

# %% [markdown]
# **Cluster 1**

# %%
toronto_merged.loc[toronto_merged['Cluster Labels'] == 0, toronto_merged.columns[[1] + list(range(5, toronto_merged.shape[1]))]]
# Out:
#              Borough  Cluster Labels 1st Popular Venues 2nd Popular Venues  \
# 58  Downtown Toronto               0        Pizza Place       Dessert Shop
#
#    3rd Popular Venues 4th Popular Venues 5th Popular Venues  \
# 58             Bakery        Yoga Studio                Spa
#
#    6th Popular Venues 7th Popular Venues      8th Popular Venues  \
# 58        Coffee Shop               Café  Furniture / Home Store
#
#      9th Popular Venues 10th Popular Venues
# 58  American Restaurant           Pet Store

# %% [markdown]
# **Cluster 2**

# %%
toronto_merged.loc[toronto_merged['Cluster Labels'] == 1, toronto_merged.columns[[1] + list(range(5, toronto_merged.shape[1]))]]
# Out:
#             Borough  Cluster Labels 1st Popular Venues 2nd Popular Venues  \
# 26     East Toronto               1  Indian Restaurant      Grocery Store
# 33     West Toronto               1  Convenience Store          Pet Store
# 51  Central Toronto               1  French Restaurant               Park
#
#     3rd Popular Venues   4th Popular Venues 5th Popular Venues  \
# 26                Café        Women's Store           Platform
# 33                Park  Sporting Goods Shop     Mattress Store
# 51  Mexican Restaurant   Italian Restaurant        Pizza Place
#
#    6th Popular Venues 7th Popular Venues  8th Popular Venues  \
# 26            Brewery       Burger Joint            Bus Line
# 33                Gym                Pub  Mexican Restaurant
# 51          BBQ Joint               Café        Liquor Store
#
#    9th Popular Venues 10th Popular Venues
# 26        Snack Place      Shopping Plaza
# 33               Pool         Pizza Place
# 51     Sandwich Place         Coffee Shop

# %% [markdown]
# **Cluster 3**

# %%
toronto_merged.loc[toronto_merged['Cluster Labels'] == 2, toronto_merged.columns[[1] + list(range(5, toronto_merged.shape[1]))]]
# Out:
#          Borough  Cluster Labels 1st Popular Venues 2nd Popular Venues  \
# 38  West Toronto               2         Restaurant               Café
#
#    3rd Popular Venues 4th Popular Venues 5th Popular Venues  \
# 38       Gourmet Shop          Gift Shop          Bookstore
#
#    6th Popular Venues 7th Popular Venues 8th Popular Venues  \
# 38          Gastropub        Gas Station                Pub
#
#    9th Popular Venues 10th Popular Venues
# 38   Sushi Restaurant             Brewery

# %% [markdown]
# **Cluster 4**

# %%
toronto_merged.loc[toronto_merged['Cluster Labels'] == 3, toronto_merged.columns[[1] + list(range(5, toronto_merged.shape[1]))]]
# Out:
#              Borough  Cluster Labels     1st Popular Venues  \
# 18      East Toronto               3            Coffee Shop
# 19      East Toronto               3  Vietnamese Restaurant
# 41  Downtown Toronto               3                   Café
#
#     2nd Popular Venues 3rd Popular Venues   4th Popular Venues  \
# 18        Skating Rink           Bus Line       Ice Cream Shop
# 19  Chinese Restaurant             Bakery   Light Rail Station
# 41                Park          Bookstore  Japanese Restaurant
#
#       5th Popular Venues 6th Popular Venues       7th Popular Venues  \
# 18   Fried Chicken Joint       Intersection            Metro Station
# 19  Fast Food Restaurant        Coffee Shop              Bridal Shop
# 41    Italian Restaurant              Hotel  Comfort Food Restaurant
#
#    8th Popular Venues      9th Popular Venues 10th Popular Venues
# 18   Sushi Restaurant  Furniture / Home Store   French Restaurant
# 19   Asian Restaurant                    Café      Breakfast Spot
# 41       Noodle House                  Museum   French Restaurant

# %% [markdown]
# **Cluster 5**

# %%
toronto_merged.loc[toronto_merged['Cluster Labels'] == 4, toronto_merged.columns[[1] + list(range(5, toronto_merged.shape[1]))]]
# Out:
#              Borough  Cluster Labels  1st Popular Venues  \
# 0   Downtown Toronto               4         Coffee Shop
# 1   Downtown Toronto               4         Coffee Shop
# 2   Downtown Toronto               4         Coffee Shop
# 3   Downtown Toronto               4          Restaurant
# 4   Downtown Toronto               4         Coffee Shop
# 5       East Toronto               4               Beach
# 6   Downtown Toronto               4         Coffee Shop
# 7   Downtown Toronto               4   Korean Restaurant
# 8   Downtown Toronto               4                Café
# 9   Downtown Toronto               4         Coffee Shop
# 10  Downtown Toronto               4      Ice Cream Shop
# 11      West Toronto               4                Café
# 12      West Toronto               4                 Bar
# 13  Downtown Toronto               4         Coffee Shop
# 14  Downtown Toronto               4                Park
# 15  Downtown Toronto               4         Coffee Shop
# 16      West Toronto               4                 Bar
# 17      West Toronto               4         Coffee Shop
# 20  Downtown Toronto               4         Coffee Shop
# 21  Downtown Toronto               4         Coffee Shop
# 22      West Toronto               4                 Bar
# 23      West Toronto               4          Theme Park
# 24      West Toronto               4  Tibetan Restaurant
# 25      East Toronto               4               Beach
# 27  Downtown Toronto               4         Coffee Shop
# 28      East Toronto               4         Coffee Shop
# 29   Central Toronto               4    Sushi Restaurant
# 30   Central Toronto               4         Coffee Shop
# 31   Central Toronto               4         Pizza Place
# 32   Central Toronto               4          Playground
# 34      West Toronto               4         Coffee Shop
# 35   Central Toronto               4         Pizza Place
# 36   Central Toronto               4            Boutique
# 37      West Toronto               4  Tibetan Restaurant
# 39   Central Toronto               4    Sushi Restaurant
# 40  Downtown Toronto               4   Korean Restaurant
# 42      West Toronto               4                Café
# 43      West Toronto               4                Park
# 44   Central Toronto               4                Park
# 45   Central Toronto               4  Italian Restaurant
# 46  Downtown Toronto               4                Café
# 47  Downtown Toronto               4         Coffee Shop
# 48  Downtown Toronto               4                Café
# 49   Central Toronto               4         Coffee Shop
# 50   Central Toronto               4          Playground
# 52   Central Toronto               4      Sandwich Place
# 53   Central Toronto               4  Italian Restaurant
# 54  Downtown Toronto               4               Hotel
# 55  Downtown Toronto               4         Coffee Shop
# 56  Downtown Toronto               4         Coffee Shop
# 57  Downtown Toronto               4         Coffee Shop
# 59  Downtown Toronto               4                Park
# 60  Downtown Toronto               4         Coffee Shop
# 61  Downtown Toronto               4         Coffee Shop
# 62  Downtown Toronto               4         Coffee Shop
# 63  Downtown Toronto               4     Bubble Tea Shop
# 64  Downtown Toronto               4    Sushi Restaurant
#
#         2nd Popular Venues             3rd Popular Venues  \
# 0                     Café                          Hotel
# 1                     Café             Italian Restaurant
# 2           Clothing Store                           Café
# 3           Clothing Store                          Hotel
# 4              Pizza Place                  Grocery Store
# 5                      Pub            Japanese Restaurant
# 6                     Café                     Restaurant
# 7              Coffee Shop             Mexican Restaurant
# 8              Coffee Shop            American Restaurant
# 9               Restaurant                          Hotel
# 10              Beer Store                  Women's Store
# 11             Pizza Place                           Park
# 12                  Bakery                           Café
# 13                    Café                          Hotel
# 14                    Café                Harbor / Marina
# 15                    Café                          Hotel
# 16                    Café                    Coffee Shop
# 17                    Café                 Clothing Store
# 20                    Café                     Restaurant
# 21                   Hotel                           Café
# 22                    Café          Vietnamese Restaurant
# 23          Soccer Stadium            Arts & Crafts Store
# 24       Indian Restaurant                          Diner
# 25                     Pub            Japanese Restaurant
# 27              Restaurant                          Hotel
# 28                    Café  Vegetarian / Vegan Restaurant
# 29      Italian Restaurant                         Bakery
# 30    Fast Food Restaurant             Italian Restaurant
# 31          Sandwich Place                   Dessert Shop
# 32  Furniture / Home Store                           Bank
# 34      Italian Restaurant                Thai Restaurant
# 35             Coffee Shop                         Bistro
# 36      Italian Restaurant                           Café
# 37       Indian Restaurant                          Diner
# 39      Italian Restaurant                    Coffee Shop
# 40                    Café                  Grocery Store
# 42             Coffee Shop                         Bakery
# 43                Bus Line                    Social Club
# 44                     Gym              Convenience Store
# 45                    Café               Sushi Restaurant
# 46            Dessert Shop                    Coffee Shop
# 47                    Café                 Ice Cream Shop
# 48             Coffee Shop                            Bar
# 49        Sushi Restaurant             Italian Restaurant
# 50  Furniture / Home Store                           Bank
# 52          History Museum                           Café
# 53                    Café               Sushi Restaurant
# 54             Coffee Shop                    Pizza Place
# 55                    Café                           Park
# 56                    Café                          Hotel
# 57      Italian Restaurant                     Restaurant
# 59              Bike Trail            Japanese Restaurant
# 60              Restaurant                           Café
# 61             Pizza Place                  Grocery Store
# 62                   Hotel                           Café
# 63                    Bank                    Fish Market
# 64             Coffee Shop            Japanese Restaurant
#
#             4th Popular Venues             5th Popular Venues  \
# 0                   Restaurant             Italian Restaurant
# 1               Sandwich Place             Chinese Restaurant
# 2                 Burger Joint                     Restaurant
# 3                  Coffee Shop                 Cosmetics Shop
# 4                         Café                       Pharmacy
# 5                     Tea Room                            Bar
# 6                        Hotel             Italian Restaurant
# 7                Grocery Store                            Pub
# 8          Japanese Restaurant                            Gym
# 9                         Café                            Gym
# 10         Filipino Restaurant           Ethiopian Restaurant
# 11        Brazilian Restaurant                            Bar
# 12                 Coffee Shop                 Sandwich Place
# 13                  Restaurant             Italian Restaurant
# 14                 Music Venue                 Farmers Market
# 15         Japanese Restaurant            Sporting Goods Shop
# 16           Korean Restaurant                   Cocktail Bar
# 17                  Restaurant                       Boutique
# 20                       Hotel            American Restaurant
# 21                  Restaurant            Japanese Restaurant
# 22                        Park                    Coffee Shop
# 23               Poutine Place                    Coffee Shop
# 24                         Bar                           Café
# 25                    Tea Room                            Bar
# 27                        Café             Italian Restaurant
# 28              Clothing Store                 Cosmetics Shop
# 29                 Coffee Shop                    Pizza Place
# 30                  Restaurant                      Bookstore
# 31            Sushi Restaurant                            Gym
# 32                        Park                   Home Service
# 34                        Café                            Bar
# 35                        Park              Indian Restaurant
# 36              Clothing Store                    Coffee Shop
# 37                         Bar                           Café
# 39                         Gym                            Pub
# 40              Sandwich Place                           Park
# 42                        Bank                    Pizza Place
# 43  Construction & Landscaping                     Restaurant
# 44               Women's Store              Electronics Store
# 45                         Spa                    Coffee Shop
# 46          Mexican Restaurant                         Bakery
# 47         Japanese Restaurant            Arts & Crafts Store
# 48          Mexican Restaurant  Vegetarian / Vegan Restaurant
# 49                        Café                  Grocery Store
# 50                        Park                   Home Service
# 52                 Coffee Shop                           Park
# 53                         Spa                    Coffee Shop
# 54              Scenic Lookout                 Ice Cream Shop
# 55             Harbor / Marina       Bike Rental / Bike Share
# 56                  Restaurant             Italian Restaurant
# 57                    Beer Bar                            Gym
# 59                  Playground                    Flea Market
# 60         Japanese Restaurant                            Pub
# 61                        Café                       Pharmacy
# 62                  Restaurant                            Gym
# 63         Sporting Goods Shop                 Breakfast Spot
# 64               Grocery Store                     Restaurant
#
#        6th Popular Venues             7th Popular Venues   8th Popular Venues  \
# 0              Sports Bar               Sushi Restaurant          Music Venue
# 1         Bubble Tea Shop                Thai Restaurant  Japanese Restaurant
# 2        Ramen Restaurant             Italian Restaurant  Japanese Restaurant
# 3               Bookstore                       Tea Room  Japanese Restaurant
# 4          Breakfast Spot           Caribbean Restaurant       Sandwich Place
# 5                  Bakery                 Breakfast Spot          Pizza Place
# 6     Japanese Restaurant                            Gym   Seafood Restaurant
# 7            Cocktail Bar            Japanese Restaurant    Indian Restaurant
# 8              Restaurant                      Gastropub       Cosmetics Shop
# 9     Japanese Restaurant                      Gastropub   Seafood Restaurant
# 10            Event Space             Falafel Restaurant                 Farm
# 11             Restaurant                    Coffee Shop         Dessert Shop
# 12             Restaurant                       Beer Bar           Beer Store
# 13             Sports Bar               Sushi Restaurant          Music Venue
# 14      Electronics Store           Ethiopian Restaurant          Event Space
# 15          Deli / Bodega                     Restaurant       Breakfast Spot
# 16             Restaurant                         Bakery        Grocery Store
# 17                   Park                         Museum          Music Store
# 20                    Gym             Seafood Restaurant        Deli / Bodega
# 21    American Restaurant                  Deli / Bodega   Seafood Restaurant
# 22      French Restaurant                       Dive Bar          Music Venue
# 23     Athletics & Sports   Theme Park Ride / Attraction        Moving Target
# 24                 Bakery                     Restaurant             Pharmacy
# 25                 Bakery                 Breakfast Spot          Pizza Place
# 27    Japanese Restaurant            American Restaurant                  Gym
# 28    Japanese Restaurant                          Hotel    Indian Restaurant
# 29                    Pub           Fast Food Restaurant     Asian Restaurant
# 30                   Park             Mexican Restaurant          Yoga Studio
# 31                   Café             Italian Restaurant          Coffee Shop
# 32            Flea Market                    Fish Market    Fish & Chips Shop
# 34             Nail Salon                   Antique Shop  Arts & Crafts Store
# 35         Ice Cream Shop                Thai Restaurant        Grocery Store
# 36             Restaurant                            Spa        Women's Store
# 37                 Bakery                     Restaurant             Pharmacy
# 39      Convenience Store                          Trail                Hotel
# 40            Coffee Shop            Japanese Restaurant   Mexican Restaurant
# 42               Tea Room             Italian Restaurant            Gastropub
# 43           Skating Rink                  Women's Store   Falafel Restaurant
# 44   Ethiopian Restaurant                    Event Space   Falafel Restaurant
# 45             Kids Store              French Restaurant            Juice Bar
# 46  Vietnamese Restaurant  Vegetarian / Vegan Restaurant       Clothing Store
# 47            Art Gallery             Chinese Restaurant    French Restaurant
# 48                 Bakery          Vietnamese Restaurant            Nightclub
# 49        Thai Restaurant                     Restaurant                 Bank
# 50            Flea Market                    Fish Market    Fish & Chips Shop
# 52                 Castle                            Pub          Pizza Place
# 53             Kids Store              French Restaurant            Juice Bar
# 54                Theater                       Aquarium                  Gym
# 55       Ramen Restaurant                         Garden        Grocery Store
# 56             Sports Bar               Sushi Restaurant          Music Venue
# 57                  Hotel                 Sandwich Place                  Bar
# 59            Fish Market              Fish & Chips Shop  Filipino Restaurant
# 60              Gastropub                          Diner           Beer Store
# 61         Breakfast Spot           Caribbean Restaurant       Sandwich Place
# 62    Japanese Restaurant            American Restaurant          Salad Place
# 63   Fast Food Restaurant             Chinese Restaurant          Gas Station
# 64                  Hotel                   Burger Joint                 Café
#
#      9th Popular Venues          10th Popular Venues
# 0                   Gym                         Bank
# 1        Ice Cream Shop            French Restaurant
# 2                 Diner    Middle Eastern Restaurant
# 3        Sandwich Place                         Café
# 4            Restaurant                   Playground
# 5                  Park                 Liquor Store
# 6          Cocktail Bar                    Gastropub
# 7             Gift Shop               Sandwich Place
# 8    Seafood Restaurant                     Tea Room
# 9    Italian Restaurant          American Restaurant
# 10       Farmers Market         Fast Food Restaurant
# 11    Electronics Store                  Flower Shop
# 12         Cocktail Bar           Mexican Restaurant
# 13                  Gym                         Bank
# 14   Falafel Restaurant                         Farm
# 15          Salad Place                  Supermarket
# 16             Boutique                    Jazz Club
# 17  Japanese Restaurant                Jewelry Store
# 20             Tea Room                       Bakery
# 21     Asian Restaurant                   Steakhouse
# 22            Gastropub            Korean Restaurant
# 23     Storage Facility                    Nightclub
# 24             Boutique           Chinese Restaurant
# 25                 Park                 Liquor Store
# 27   Seafood Restaurant                Deli / Bodega
# 28           Shoe Store                   Restaurant
# 29                 Bank              Bubble Tea Shop
# 30        Movie Theater                  Pizza Place
# 31           Restaurant                          Bar
# 32  Filipino Restaurant         Fast Food Restaurant
# 34   Mexican Restaurant                     Bus Stop
# 35           Donut Shop    Middle Eastern Restaurant
# 36     Sushi Restaurant            French Restaurant
# 37             Boutique           Chinese Restaurant
# 39   Falafel Restaurant               Sandwich Place
# 40       Ice Cream Shop         Fast Food Restaurant
# 42                  Pub    Latin American Restaurant
# 43  Egyptian Restaurant            Electronics Store
# 44                 Farm               Farmers Market
# 45         Liquor Store                       Bakery
# 46                  Bar             Ramen Restaurant
# 47       Clothing Store               Sandwich Place
# 48         Dessert Shop                Grocery Store
# 49       Sandwich Place                          Gym
# 50  Filipino Restaurant         Fast Food Restaurant
# 52             Pharmacy                   Donut Shop
# 53         Liquor Store                       Bakery
# 54     Baseball Stadium               Sandwich Place
# 55  Japanese Restaurant                         Bank
# 56                  Gym                         Bank
# 57    French Restaurant            Indian Restaurant
# 59          Flower Shop  Eastern European Restaurant
# 60               Bakery            Indian Restaurant
# 61           Restaurant                   Playground
# 62     Asian Restaurant           Seafood Restaurant
# 63       Sandwich Place               Clothing Store
# 64                Diner                    Gastropub
